# %% [markdown]
# # Robinhood Tracking
# > **Goal**: Captures fundamentals on provided companies. <br>
# > **Notebook Owner(s):** Time Bioventures <br>
# > **Date:** July 2024 <br>

# %% [markdown]
# ***
# ## Import Libraries
#
# Import the libraries you will be using throughout the project.

# %%
# Imports
import os
import sys
import json
import numpy as np
import pandas as pd
from pprint import pprint
from datetime import datetime, timedelta
import matplotlib.pyplot as plt
import plotly.graph_objects as go
from plotly.subplots import make_subplots
import helper.login_helper as login_helper

rs_installed = login_helper.login_helper()
# Out:
# ERROR: There was an issue loading pickle file. Authentication may be expired - logging in normally.
# robin_stocks imported

# %% [markdown]
# ***
# ## Holdings
# `create_holdings_df()` captures all current holdings and inserts into a pandas DataFrame for viewing

# %%
import pytz
import robin_stocks.robinhood as rs
from collections import defaultdict

def create_holdings_df():
	'''
	create_holdings_df requests all holdings information from 
	robinhood, builds a pandas DataFrame to capture all the 
	data, and returns the DataFrame
	'''
	nytz = pytz.timezone('America/New_York')
	holding_dict = defaultdict(str)
	my_holdings = rs.build_holdings()
	holdings_df = pd.DataFrame(my_holdings).T
	cols = list(holdings_df.columns.values)
	cols = ['name']  + [col for col in holdings_df if col != 'name']
	holdings_df = holdings_df[cols]
	return holdings_df

holdings_df = create_holdings_df()
holdings_df
# Out:
#                        name       price      quantity average_buy_price  \
# SPY        SPDR S&P 500 ETF  546.520000    1.56288200          405.4753
# GOOG       Alphabet Class C  173.050000   16.01796000           97.9270
# AAPL                  Apple  220.280000   22.79212100          128.9358
# ENPH         Enphase Energy  113.000000    0.75363200          159.9557
# ALVR                AlloVir    0.740000    0.63708000           15.6151
# CMPS       Compass Pathways    7.140000    6.23831500           27.1493
# AMZN                 Amazon  187.060000    5.00000000          150.7540
# DNA         Ginkgo Bioworks    0.381200   40.89477700           12.2265
# LEU          Centrus Energy   40.810000   47.71139900           43.7338
# MVIS            MicroVision    1.015000  195.00000000            6.1919
# ME                  23andMe    0.387000  100.00000000            9.1750
# CX                    Cemex    6.355000  100.32649800            8.0075
# X       United States Steel   40.795000   35.69377100           27.8702
# SPOT                Spotify  341.260000    1.00000000          224.7900
# PLTR  Palantir Technologies   26.710000   18.74414200           26.6750
#
#        equity percent_change intraday_percent_change equity_change   type  \
# SPY    854.15          34.79                   -0.65    220.436223    etp
# GOOG  2771.91          76.71                    0.00   1203.317209  stock
# AAPL  5020.65          70.84                    0.00   2081.928059  stock
# ENPH    85.16         -29.36                    0.00    -35.387318  stock
# ALVR     0.47         -95.26                    0.00     -9.476629  stock
# CMPS    44.54         -73.70                    0.00   -124.824316    adr
# AMZN   935.30          24.08                    0.00    181.530000  stock
# DNA     15.59         -96.88                    0.00   -484.410902  stock
# LEU   1947.10          -6.69                    0.00   -139.498588  stock
# MVIS   197.92         -83.61                    0.00  -1009.495500  stock
# ME      38.70         -95.78                    0.00   -878.800000  stock
# CX     637.57         -20.64                    0.00   -165.789538    adr
# X     1456.13          46.37                    0.00    461.334851  stock
# SPOT   341.26          51.81                    0.00    116.470000  stock
# PLTR   500.66           0.13                    0.00      0.656045  stock
#
#                                         id    pe_ratio percentage
# SPY   8f92e76f-1e0e-4478-8580-16a6ffcfaef5   25.940980       5.75
# GOOG  943c5009-a0bb-4665-8cf4-a95dab5874e4   24.836800      18.67
# AAPL  450dfc6d-5510-4d40-abfb-f633b7d9be3e   34.533800      33.81
# ENPH  69cbc174-ead1-49a9-9c72-a8f015de474f  125.803000       0.57
# ALVR  fde8cc68-e63a-4a3a-b97b-897a99d203f9   -0.450000       0.00
# CMPS  933c11d8-70dc-482d-8116-8d879c9239cf   -3.850000       0.30
# AMZN  c0bb3aec-bd1e-471e-a4f0-ca011cbec711   52.513600       6.30
# DNA   bf0e8f54-791a-4237-a034-934db7fbd219   -0.870000       0.10
# LEU   55da1c15-28c0-47f4-ada6-e0fcb3f9cc9e    9.610010      13.11
# MVIS  0d44bf53-5511-4269-99bc-8c73029db529   -2.240000       1.33
# ME    b6e11e67-a17e-44a1-863a-7c6ad4dd513f   -0.290000       0.26
# CX    201c3881-3f3d-4e5b-bae4-67f88046b001   55.154600       4.29
# X     b060f19f-0d24-4bf2-bf8c-d57ba33993e5   12.102700       9.81
# SPOT  9c53326c-d07e-4b82-82d2-b108ec5d9530  135.628000       2.30
# PLTR  f90de184-4f73-4aad-9a5f-407858013eb1  212.234000       3.37

# %% [markdown]
# ***
# ## Order History
#
# `create_orders_df()` captures all the stock orders (both buys and sells) executed on Robinhood, and inserts it into a pandas DataFrame for viewing

# %%
def create_orders_df():
	nytz = pytz.timezone('America/New_York')
	order_dict = defaultdict(str)
	orders_dict_list = []
	my_orders = rs.get_all_stock_orders()
	for order in my_orders:
		if order['state'] == 'cancelled':
			continue
		stock_url = order['instrument']
		stock_info = rs.stocks.get_instrument_by_url(stock_url)
		order_dict['ticker'] = stock_info['symbol']
		order_dict['name'] = stock_info['simple_name']
		try:
			order_dict['avg_price'] = float(order['average_price'])
		except:
			order_dict['avg_price'] = 0 # received as gift or free stock
		try:
			order_dict['latest_price'] = float(rs.stocks.get_latest_price(order_dict['ticker'])[0])
			order_dict['quantity'] = float(order['cumulative_quantity'])
			order_dict['total_amt'] = order_dict['avg_price'] * order_dict['quantity']
			date_time = datetime.strptime(order['created_at'],
							'%Y-%m-%dT%H:%M:%S.%fZ').astimezone(nytz)
			order_dict['current_val'] = order_dict['latest_price']*order_dict['quantity'] 
			order_dict['date'] = date_time.date()
			order_dict['time'] = date_time.time()
			order_dict['order_type'] = order['side']
			order_df = pd.DataFrame(order_dict, index=[0])
			orders_dict_list.append(order_df)
		except:
			pass
		
	orders_df = pd.concat(orders_dict_list, ignore_index=True)
	return orders_df
	
orders_df = create_orders_df()
orders_df
# Out:
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/?symbols=TWTR
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/?symbols=RUBY
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/?symbols=NAKD
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/?symbols=NAKD
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/?symbols=RUBY
# 400 Client Error: Bad Request for url: https://api.robinhood.com/quotes/?symbols=RUBY
#     ticker                   name  avg_price  latest_price   quantity  \
# 0       CX                  Cemex     6.3400        6.8550   0.326498
# 1     GOOG       Alphabet Class C   178.1737      189.2400   0.017960
# 2        X    United States Steel    36.4001       39.8600   0.048901
# 3     AAPL                  Apple   190.2501      235.6397   0.029908
# 4      SPY       SPDR S&P 500 ETF   500.9089      563.9601   0.004951
# ..     ...                    ...        ...           ...        ...
# 143   NTLA  Intellia Therapeutics    29.1100       26.2400  10.000000
# 144   EDIT        Editas Medicine    36.3200        5.5150   8.000000
# 145   NTLA  Intellia Therapeutics    25.9100       26.2400   5.000000
# 146   EDIT        Editas Medicine    36.1675        5.5150   8.000000
# 147   SPOT                Spotify   159.9967      307.4200   3.000000
#
#       total_amt  current_val        date             time order_type
# 0      2.069997     2.238144  2024-06-27  01:08:23.272172        buy
# 1      3.200000     3.398750  2024-06-18  01:48:36.659694        buy
# 2      1.780001     1.949194  2024-06-13  00:43:00.830651        buy
# 3      5.690000     7.047512  2024-05-17  01:34:23.687418        buy
# 4      2.480000     2.792166  2024-05-01  00:58:02.605489        buy
# ..          ...          ...         ...              ...        ...
# 143  291.100000   262.400000  2018-07-17  00:58:06.581995        buy
# 144  290.560000    44.120000  2018-06-14  13:37:26.599966       sell
# 145  129.550000   131.200000  2018-06-14  13:10:37.245826        buy
# 146  289.340000    44.120000  2018-06-12  14:35:02.106426        buy
# 147  479.990100   922.260000  2018-05-16  15:08:48.146010        buy
#
# [148 rows x 10 columns]

# %% [markdown]
# ***
# ## Search Company Info

# %%
selected_company = 'AGIOS'
company_info = rs.find_instrument_data(selected_company)
company_info_df = pd.DataFrame(company_info)
company_info_df
# Out:
# Found 1 results
#                                      id  \
# 0  c2186355-945c-48c6-9b1c-0df7dbd9d957
#
#                                                  url  \
# 0  https://api.robinhood.com/instruments/c2186355...
#
#                                     quote  \
# 0  https://api.robinhood.com/quotes/AGIO/
#
#                                    fundamentals  \
# 0  https://api.robinhood.com/fundamentals/AGIO/
#
#                                               splits   state  \
# 0  https://api.robinhood.com/instruments/c2186355...  active
#
#                                     market simple_name  \
# 0  https://api.robinhood.com/markets/XNAS/       Agios
#
#                                        name  tradeable  ...  \
# 0  Agios Pharmaceuticals, Inc. Common Stock       True  ...
#
#   internal_halt_sessions internal_halt_start_time internal_halt_end_time  \
# 0                   None                     None                   None
#
#   internal_halt_source all_day_tradability  \
# 0                               untradable
#
#   notional_estimated_quantity_decimals tax_security_type  \
# 0                                    5             stock
#
#   reserved_buying_power_percent_queued  \
# 0                           0.10000000
#
#   reserved_buying_power_percent_immediate otc_market_tier
# 0                              0.05000000
#
# [1 rows x 45 columns]

# %% [markdown]
# ### Company Fundamentals

# %%
company_symbol = company_info[0]['symbol']
# get market cap and sector
company_fundamentals = rs.stocks.get_fundamentals(company_symbol)
# show as pandas
company_fundamentals_df = pd.DataFrame(company_fundamentals)
company_fundamentals_df
# Out:
#         open       high        low        volume overnight_volume   bounds  \
# 0  46.300000  46.490000  45.240000  95558.000000         0.000000  regular
#
#   market_date average_volume_2_weeks average_volume average_volume_30_days  \
# 0  2024-07-15          604622.700000  604622.700000          722077.150000
#
#    ... headquarters_state             sector                industry  \
# 0  ...      Massachusetts  Health Technology  Pharmaceuticals: Major
#
#   num_employees year_founded payable_date ex_dividend_date  \
# 0           383         2007         None             None
#
#   financial_status_indicator financial_status_description symbol
# 0                        CC0                                AGIO
#
# [1 rows x 34 columns]

# %%
company_list = ['Pfizer', 'Amgen', 'Novartis', 'Eli Lilly', 'Gilead', 'Abbvie', 'Biogen', 'Regeneron', 'Vertex', 'Agios']
for company in company_list:
	company_index = 0
	print(f'{company}:')
	company_info = rs.find_instrument_data(company)
	if len(company_info) > 1:
		for i, info in enumerate(company_info):
			# find industry
			company_fundamentals = rs.stocks.get_fundamentals(info['symbol'])
			company_sector = company_fundamentals[0]['industry']
			print(f'  {company}: {info["symbol"]} - {company_sector}')
			if 'pharma' in company_sector.lower():
				company_index = i
				break
	company_symbol = company_info[company_index]['symbol']
	# get market cap and sector
	company_fundamentals = rs.stocks.get_fundamentals(company_symbol)
	company_market_cap = int(float(company_fundamentals[0]['market_cap']))
	company_sector = company_fundamentals[0]['industry']
	company_employee = company_fundamentals[0]['num_employees']
	print(f'  {company}: {company_symbol} - {company_sector}')
	print(f'    Market Cap - ${company_market_cap}')
	print(f'    Employee Count - {company_employee}')
# Out:
# Pfizer:
# Found 1 results
#   Pfizer: PFE - Pharmaceuticals: Major
#     Market Cap - $163933961403
#     Employee Count - 88000
# Amgen:
# Found 1 results
#   Amgen: AMGN - Pharmaceuticals: Major
#     Market Cap - $177511705850
#     Employee Count - 26700
# Novartis:
# Found 1 results
#   Novartis: NVS - Pharmaceuticals: Major
#     Market Cap - $243747962844
#     Employee Count - 76057
# Eli Lilly:
# Found 1 results
#   Eli Lilly: LLY - Pharmaceuticals: Major
#     Market Cap - $904662398008
#     Employee Count - 43000
# Gilead:
# Found 1 results
#   Gilead: GILD - Biotechnology
#     Market Cap - $88555252082
#     Employee Count - 18000
# Abbvie:
# Found 1 results
#   Abbvie: ABBV - Pharmaceuticals: Major
#     Market Cap - $297937586400
#     Employee Count - 50000
# Biogen:
# Found 1 results
#   Biogen: BIIB - Pharmaceuticals: Major
#     Market Cap - $32902010060
#     Employee Count - 7570
# Regeneron:
# Found 1 results
#   Regeneron: REGN - Pharmaceuticals: Major
#     Market Cap - $120628861118
#     Employee Count - 13450
# Vertex:
# Found 3 results
#   Vertex: VERX - Packaged Software
#   Vertex: VRTX - Pharmaceuticals: Major
#   Vertex: VRTX - Pharmaceuticals: Major
#     Market Cap - $127443546501
#     Employee Count - 5400
# Agios:
# Found 1 results
#   Agios: AGIO - Pharmaceuticals: Major
#     Market Cap - $2636538120
#     Employee Count - 383

# %% [markdown]
# ***
# ## TO DO

# %% [markdown]
# ## Correlation between tickers
#
# Also consider reading this paper: [Life time of correlation between stocks prices on established and emerging markets](https://arxiv.org/pdf/1105.6272.pdf)
#
# > **Abstract:** The correlation coefficient between stocks depends on price history and
# includes information on hierarchical structure in financial markets. It is
# useful for portfolio selection and estimation of risk. I introduce the Life
# Time of Correlation between stocks prices to know how far we should
# investigate the price history to obtain the optimal durability of correlation. I
# carry out my research on emerging (Poland) and established markets (in the
# USA, Great Britain and Germany). Other methods, including the Minimum
# Spanning Trees, tree half-life, decomposition of correlations and the Epps
# effect are also discussed.

# %% [markdown]
# ***
# ## Interactive Historical Data

# %%
import pytz
from datetime import datetime, timedelta

nytz = pytz.timezone('America/New_York')

def plot_ticker(ticker,timescale):
	buy_color="green"
	sell_color="red"

	if timescale=='long':
	# Get historical data
		ticker_data = rs.stocks.get_stock_historicals(ticker, interval='day', span='5year')
		df = pd.DataFrame(ticker_data)
		df.begins_at = df.begins_at.map(lambda x: datetime.strptime(x,"%Y-%m-%dT%H:%M:%SZ"))
		df.begins_at = df.begins_at.map(lambda x: x+timedelta(hours=12))

	elif timescale=='short':
		ticker_data = rs.stocks.get_stock_historicals(ticker, interval='5minute', span='day', bounds='extended')
		# Convert timezones
		df = pd.DataFrame(ticker_data)
		df.begins_at = pd.to_datetime(df.begins_at)
		df.begins_at = df['begins_at'].dt.tz_convert('America/New_York')
	
	# Reformat names
	df = df.rename(columns={'begins_at':'date',
							'open_price':'open',
							'high_price':'high',
							'low_price':'low',
							'close_price':'close'})

	# Set colors
	increasing_color = '#17BECF'
	decreasing_color = '#7F7F7F'
	# create volume chart colors
	colors = []
	for i in range(len(df.close)):
		if i != 0:
			if df.close[i] > df.close[i-1]:
				colors.append(increasing_color)
			else:
				colors.append(decreasing_color)
		else:
			colors.append(decreasing_color)

	# Initial candlestick chart
	layout = dict()
	fig = make_subplots(rows=2, cols=1, shared_xaxes=True, 
				vertical_spacing=0.01, 
				row_width=[0.2, 0.8])
	# OHLC
	fig.add_trace(go.Candlestick(x=df.date,
								open=df.open,
								high=df.high,
								low=df.low,
								close=df.close,
								increasing_line_color=increasing_color,
								decreasing_line_color=decreasing_color ,
								showlegend=False
								), row=1, col=1)
	# Volume
	fig.add_trace(go.Bar(x=df.date, 
						y=df.volume, 
						showlegend=True, 
						name='Volume',
						marker=dict(color=colors)
						), row=2, col=1)
	if timescale=='long':
		# MA50
		df['MA50'] = df.close.rolling(50).mean()
		fig.add_trace(go.Scatter(x=df.date, 
								y=df.MA50, 
								line=dict(color='#b300ff', width=1),
								name='MA50',
								showlegend=True
								), row=1, col=1)
		# MA200
		df['MA200'] = df.close.rolling(200).mean()
		fig.add_trace(go.Scatter(x=df.date, 
								y=df.MA200, 
								line=dict(color='#5900ff', width=1),
								name='MA200'
								), row=1, col=1)

	# Add individual orders to plot
	# orders = rs.find_stock_orders(symbol=holding)
	'''
	order_history = get_order_history(ticker)
	orders = order_history[ticker]['orders']
	if orders:
	for order in orders:      
		if order['side'] == 'buy':
		fig.add_annotation(x=order["timestamp"],
							y=float(order["price"]),
							text=str(order["quantity"])+'sh=*$'+str(float(order["price"])),
							showarrow=True,
							arrowhead=1,
							arrowcolor=buy_color,
							align='right',
							font=dict(color=buy_color,size=6))
		elif order['side'] == 'sell':
		fig.add_annotation(x=order["timestamp"],
							y=float(order["price"]),
							text=str(order["quantity"])+'sh=*$'+str(float(order["price"])),
							showarrow=True,
							arrowhead=1,
							arrowcolor=sell_color,
							align='right',
							font=dict(color=sell_color,size=6))
	# Average buy price
	avg_buy_price = order_history[ticker]['total']['avg_cost']
	print(f'Average buy price: ${round(avg_buy_price,2)}')
	fig.add_shape(type='line', xref='paper',yref='y',
					x0=0, x1=1, 
					y0=avg_buy_price, y1=avg_buy_price,
					line=dict(width=0.5, color='black')
					)
	fig.add_annotation(xref='paper',yref='y',
						x=0, y=avg_buy_price, 
						text='Average buy price: $'+str(round(avg_buy_price,2)),
						showarrow=False,
						align='right',
						font=dict(color='black',size=9)
						)
	'''
	# # Add range buttons
	fig.update_layout(
		xaxis=dict(
			rangeselector=dict(
				buttons=list([
					dict(count=1,
						 label="1d",
						 step="day",
						 stepmode="backward"),
					dict(count=7,
						 label="1w",
						 step="day",
						 stepmode="backward"),
					dict(count=1,
						label="1m",
						step="month",
						stepmode="backward"),
					dict(count=3,
						label="3m",
						step="month",
						stepmode="backward"),
					dict(count=6,
						label="6m",
						step="month",
						stepmode="backward"),
					dict(count=1,
						label="YTD",
						step="year",
						stepmode="todate"),
					dict(count=1,
						label="1y",
						step="year",
						stepmode="backward"),
					dict(step="all")
				])
			),
			type="date"
		),
		title=ticker,
		yaxis_title='Price (adjusted)'
	)
	fig.update_xaxes(type='date', row=2, col=1)
	fig.update_yaxes(title='Volume', row=2, col=1)
	fig.update(layout_xaxis_rangeslider_visible=False)
	fig.show()

# %%
plot_ticker('AGIO', 'long')
# Out:
# /opt/anaconda3/lib/python3.11/site-packages/_plotly_utils/basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
# /opt/anaconda3/lib/python3.11/site-packages/_plotly_utils/basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result
#
# /opt/anaconda3/lib/python3.11/site-packages/_plotly_utils/basevalidators.py:106: FutureWarning:
#
# The behavior of DatetimeProperties.to_pydatetime is deprecated, in a future version this will return a Series containing python datetime objects instead of an ndarray. To retain the old behavior, call `np.array` on the result

# %%
all_biopharmaceuticals = rs.markets.get_all_stocks_from_market_tag(tag='biopharmaceutical')
biopharma_df = pd.DataFrame()
for stock in all_biopharmaceuticals:
	stock_ticker = stock['symbol']
	# get name and market cap
	company_info = rs.find_instrument_data(stock_ticker)
	try:
		stock_name = company_info[0]['simple_name']
	except:
		stock_name = 'NA'
	stock_info = rs.stocks.get_fundamentals(stock_ticker)
	try:
		stock_market_cap = int(float(stock_info[0]['market_cap']))
	except:
		stock_market_cap = 'NA'
	print(f'{stock_name}: {stock_ticker} - ${stock_market_cap}')
	# insert all company info and stock info into database
	stock_dict = {'name':stock_name, 'ticker':stock_ticker, 'market_cap':stock_market_cap}
	stock_df = pd.DataFrame(stock_dict, index=[0])
	biopharma_df = pd.concat([biopharma_df, stock_df], ignore_index=True)
# Out:
# Found 1 results
# Phathom Pharmaceuticals: PHAT - $676081560
# Found 1 results
# Matinas BioPharma: MTNB - $41368961
# Found 1 results
# BioLineRx: BLRX - $61332525
# Found 1 results
# Bristol-Myers Squibb: BMY - $97293101340
# Found 1 results
# ADMA Biologics: ADMA - $2858207423
# Found 1 results
# Apellis Pharmaceuticals: APLS - $4337620840
# Found 1 results
# Alnylam Pharmaceuticals: ALNY - $33125092500
# Found 1 results
# Intra-Cellular Therapies: ITCI - $8251214125
# Found 1 results
# CSL Limited: CSLLY - $96789283449
# Found 1 results
# AbbVie: ABBV - $334941392250
# Found 1 results
# Denali Therapeutics: DNLI - $3354877164
# Found 4 results
# Exelixis: EXEL - $6979380280
# Found 1 results
# Dynavax: DVAX - $1447665520
# No results found for that keyword
# NA: SRNE - $4685889
# Found 1 results
# Omeros: OMER - $289721000
# Found 1 results
# Cytokinetics: CYTK - $6836514560
# Found 1 results
# Theravance Biopharma: TBPH - $477821414
# Found 1 results
# DiaMedica Therapeutics Inc. Common Stock: DMAC - $148957024
# Found 1 results
# Incyte: INCY - $12679627960
# Found 1 results
# TG Therapeutics: TGTX - $2985770760
# Found 1 results
# RAPT Therapeutics: RAPT - $107153745
# Found 2 results
# Ocular Therapeutix: OCUL - $1246856450
# Found 1 results
# BioXcel Therapeutics: BTAI - $41659208
# Found 2 results
# Gilead Sciences: GILD - $95208228535
# Found 1 results
# XBiotech: XBIT - $228431476
# Found 2 results
# Sage Therapeutics: SAGE - $603553549
# Found 2 results
# Kura Oncology: KURA - $1553322767
# Found 1 results
# Puma Biotechnology: PBYI - $167871024
# Found 10 results
# Spero Therapeutics: SPRO - $76930961
# Found 1 results
# MannKind: MNKD - $1535862240
# Found 1 results
# XTL Biopharmaceuticals: XTLB - $15257368
# Found 1 results
# Axsome Therapeutics: AXSM - $4063030496
# Found 1 results
# InflaRx: IFRX - $90680282
# Found 1 results
# Eyenovia: EYEN - $71892425
# Found 1 results
# Fate Therapeutics: FATE - $585096480
# Found 1 results
# Arvinas: ARVN - $1838422993
# No results found for that keyword
# NA: RVLPQ - $11140
# Found 1 results
# Nektar Therapeutics: NKTR - $238305900
# Found 1 results
# Entera Bio: ENTX - $61964013
# Found 2 results
# SELLAS Life Sciences: SLS - $66418165
# Found 1 results
# Sarepta Therapeutics: SRPT - $13468696262
# Found 1 results
# Alkermes: ALKS - $4404877826
# Found 3 results
# Kodiak Sciences: KOD - $147097856
# Found 1 results
# Insmed Incorporated: INSM - $11934754650
# Found 1 results
# Arrowhead Pharmaceuticals: ARWR - $3436620266
# Found 1 results
# Morphic: MORF - $2853767499
# Found 1 results
# Halozyme Therapeutics: HALO - $7000070000
# Found 2 results
# Esperion Therapeutics: ESPR - $420942876
# No results found for that keyword
# NA: INFIQ - $9076
# Found 1 results
# Cyclacel Pharmaceuticals (Preferred): CYCCP - $2399744
# Found 1 results
# Fennec Pharmaceuticals: FENC - $167372250
# Found 1 results
# Applied Therapeutics: APLT - $675891553
# Found 1 results
# Akebia Therapeutics: AKBA - $279811160
# Found 1 results
# MacroGenics: MGNX - $246775990
# Found 1 results
# Quince Therapeutics: QNCX - $31589750
# Found 1 results
# Jazz Pharmaceuticals: JAZZ - $7122898080
# Found 1 results
# Scholar Rock: SRRK - $725762310
# Found 7 results
# Adaptimmune Therapeutics: ADAP - $332144567
# Found 1 results
# Y-mAbs: YMAB - $514743315
# Found 1 results
# Catalyst Pharmaceuticals: CPRX - $2003231795
# Found 4 results
# Standard BioTools: LAB - $511070498
# Found 1 results
# Regeneron: REGN - $120415124542
# Found 1 results
# Alector: ALEC - $566741448
# Found 3 results
# Milestone Pharmaceuticals: MIST - $72979352
# Found 1 results
# Cue Biopharma: CUE - $41361397
# Found 1 results
# Amgen: AMGN - $180290439150
# Found 1 results
# Ascendis Pharma: ASND - $7728429696
# Found 1 results
# AstraZeneca: AZN - $249272731319
# Found 1 results
# Cellectis: CLLS - $156897301
# Found 1 results
# SpringWorks: SWTX - $2637476475
# No results found for that keyword
# NA: SNNAQ - $31
# Found 1 results
# Geron: GERN - $2847038400
# Found 1 results
# MediciNova: MNOV - $65721971
# Found 7 results
# AIM ImmunoTech: AIM - $20003558
# Found 1 results
# Liquidia: LQDA - $900154957
# Found 1 results
# Autolus Therapeutics: AUTL - $1214454939
# Found 1 results
# Veru: VERU - $130676996
# Found 1 results
# Emergent BioSolutions: EBS - $613102230
# Found 1 results
# BioCryst: BCRX - $1464245499
# Found 1 results
# Anavex: AVXL - $557954390
# Found 1 results
# Chimerix: CMRX - $78058679
# Found 1 results
# Ligand Pharmaceuticals: LGND - $1896526609
# Found 1 results
# Amarin: AMRN - $267984844
# Found 1 results
# Protagonist Therapeutics: PTGX - $2233913069
# Found 1 results
# Alimera Sciences: ALIM - $292944168
# Found 1 results
# Avid Bioservices: CDMO - $666012022
# Found 1 results
# PTC Therapeutics: PTCT - $2534829240
# Found 1 results
# GENFIT: GNFT - $225939869
# Found 1 results
# Zai Lab: ZLAB - $1856268765
# Found 1 results
# Beyond Air: XAIR - $25901821
# Found 1 results
# Innate Pharma: IPHA - $187906771
# Found 1 results
# NextCure: NXTC - $44757280
# Found 1 results
# BeiGene: BGNE - $18254411447
# Found 1 results
# AC Immune: ACIU - $398279303
# Found 1 results
# Viking Therapeutics: VKTX - $6298764226
# Found 1 results
# Clearside Biomedical: CLSD - $83698874
# Found 1 results
# G1 Therapeutics: GTHX - $221934543
# Found 1 results
# Corvus Pharmaceuticals: CRVS - $160756841
# Found 1 results
# Agios: AGIO - $2513908440
# Found 1 results
# Fulcrum Therapeutics: FULC - $572434979
# Found 1 results
# Verona Pharma: VRNA - $1859205026
# Found 1 results
# Ardelyx: ARDX - $1308914133
# Found 1 results
# Lexicon Pharmaceuticals: LXRX - $735636787
# Found 1 results
# 89bio, Inc: ETNB - $922841930
# Found 1 results
# Mirum Pharmaceuticals: MIRM - $1909122878
# Found 1 results
# ProQR Therapeutics: PRQR - $155966662
# Found 5 results
# Ultragenyx Pharmaceutical: RARE - $4053879420
# Found 1 results
# ARCA biopharma: ABIO - $42360857
# Found 1 results
# Aclaris Therapeutics: ACRS - $97276452
# Found 1 results
# Trevi Therapeutics: TRVI - $209896598
# No results found for that keyword
# NA: NYMXF - $27379

# %%
'''
[{'open': '30.738000',
'high': '30.810000',
'low': '29.910000',
'volume': '14833541.000000',
'overnight_volume': '0.000000',
'bounds': 'regular',
'market_date': '2024-08-01',
'average_volume_2_weeks': '42939487.400000',
'average_volume': '42939487.400000',
'average_volume_30_days': '35502187.772700',
'high_52_weeks': '37.186000',
'high_52_weeks_date': '2023-08-21',
'dividend_yield': '5.435490',
'float': '5664142033.120000',
'low_52_weeks': '25.200000',
'low_52_weeks_date': '2024-04-26',
'market_cap': '172942708105.157379',
'pb_ratio': '1.875450',
'pe_ratio': '-66.220000',
'shares_outstanding': '5666592663.268557',
'description': 'Pfizer Inc. is a research-based global biopharmaceutical company, which engages in the discovery, development, manufacture, marketing, sales and distribution of biopharmaceutical products worldwide. The firm works across developed and emerging markets to advance wellness, prevention, treatments and cures that challenge the most feared diseases. The company was founded by Charles Pfizer Sr. and Charles Erhart in 1849 and is headquartered in New York, NY.',
'instrument': 'https://api.robinhood.com/instruments/6ec6c70e-d686-4d73-b5a8-74fec96aca0e/',
'ceo': 'Albert Bourla',
'headquarters_city': 'New York',
'headquarters_state': 'New York',
'sector': 'Health Technology',
'industry': 'Pharmaceuticals: Major',
'num_employees': 88000,
'year_founded': 1849,
'payable_date': '2024-09-03',
'ex_dividend_date': '2024-07-26',
'financial_status_indicator': 'CA0',
'financial_status_description': '',
'symbol': 'PFE'}]
'''

def get_stock_data(stock_ticker, info_type='fundamentals'):
	'''
	get_stock_data returns the requested fields for the stock
	'''
	if info_type == 'instrument_data':
		stock_info = rs.find_instrument_data(stock_ticker)
	if info_type == 'fundamentals':
		stock_info = rs.stocks.get_fundamentals(stock_ticker)
	stock_dict = {}
	if not stock_info[0]:
		return stock_dict
	for field in stock_info[0].keys():
		try:
			stock_dict[field] = stock_info[0][field]
		except:
			stock_dict[field] = 'NA'
	return stock_dict

def get_all_healthcare_stocks():
	'''
	get_all_healthcare_stocks returns all stocks that are tagged
	with healthcare, biopharmaceutical, biotechnology, or pharmaceutical
	'''
	all_healthcare_stocks = []
	healthcare_terms = ['healthcare', 'biopharmaceutical', 'biotechnology', 'pharmaceutical']
	for term in healthcare_terms:
		stocks = rs.markets.get_all_stocks_from_market_tag(tag=term)
		all_healthcare_stocks.extend(stocks)

	healthcare_df = pd.DataFrame()
	for stock in all_healthcare_stocks:
		stock_ticker = stock['symbol']
		# get name and market cap
		company_dict = get_stock_data(stock_ticker, 'instrument_data')
		stock_dict = get_stock_data(stock_ticker, 'fundamentals')
		print(f'{stock_name}: {stock_ticker} - ${stock_dict["market_cap"]}')
		# insert all company info and stock info into database
		columns = list(company_dict.keys()) + list(stock_dict.keys())
		values = list(company_dict.values()) + list(stock_dict.values())
		stock_dict = dict(zip(columns, values))
		stock_df = pd.DataFrame(stock_dict, index=[0])
		if len(healthcare_df) == 0 or stock_ticker not in healthcare_df['symbol'].values:
			healthcare_df = pd.concat([healthcare_df, stock_df], ignore_index=True)
	return healthcare_df

healthcare_df = get_all_healthcare_stocks()
# Out:
# Found 1 results
# NA: WEX - $7456342584.815792
# Found 2 results
# NA: UNICY - $19912337804.081337
# Found 1 results
# NA: SRTS - $102782229.000000
# Found 1 results
# NA: MCK - $80999331060.000000
# Found 1 results
# NA: STRM - $30394700.000000
# Found 7 results
# NA: UG - $49802428.800000
# Found 1 results
# NA: PTH - $144417000.000000
# Found 1 results
# NA: CTRE - $3846389980.498884
# Found 1 results
# NA: ABM - $3441643115.111025
# Found 9 results
# NA: HEAR - $299166136.143750
# Found 1 results
# NA: ICUI - $3054765420.000000
# No results found for that keyword
# NA: MDRX - $1044108000.000000
# Found 2 results
# NA: NVO - $595643184105.054321
# Found 7 results
# NA: PRA - $635712790.200000
# Found 3 results
# NA: CAE - $5577622923.290777
# Found 1 results
# NA: JNJ - $382679527755.995789
# Found 3 results
# NA: MBIN - $2016868003.724454
# Found 10 results
# NA: COR - $48231482640.000000
# Found 1 results
# NA: FXH - $1274898219.810000
# Found 1 results
# NA: HAE - $4522087625.000000
# Found 1 results
# NA: HELE - $1298990246.023007
# Found 1 results
# NA: HSIC - $9235038120.000000
# Found 1 results
# NA: ONEXF - $5113231698.000000
# Found 2 results
# NA: FMS - $11046516610.617409
# Found 2 results
# NA: OMI - $1251528548.000000
# Found 1 results
# NA: MLAB - $595602919.892440
# Found 1 results
# NA: CCRN - $617935757.000000
# Found 1 results
# NA: BAYRY - $29119047360.000000
# Found 1 results
# NA: RGP - $375873690.796307
# Found 2 results
# NA: OHI - $9011700530.000000
# Found 1 results
# NA: ATGE - $2891187720.000000
# Found 1 results
# NA: OMRNY - $7282839541.923453
# Found 1 results
# NA: ENSG - $7957081336.304599
# Found 1 results
# NA: MSBI - $491503584.000000
# Found 1 results
# NA: DGX - $16399250914.382875
# Found 1 results
# NA: FHLC - $3069259500.000000
# Found 1 results
# NA: RXL - $91766300.000000
# Found 1 results
# NA: PMM - $292989293.742600
# Found 1 results
# NA: HURN - $1960651562.000000
# Found 1 results
# NA: TBRG - $162829205.000000
# Found 1 results
# NA: ASTH - $2625111347.853595
# Found 1 results
# NA: INOD - $521002548.000000
# Found 1 results
# NA: SPXV - $21494780.000000
# Found 1 results
# NA: HCSG - $816021184.000000
# Found 1 results
# NA: HQY - $6709822419.000000
# Found 1 results
# NA: AVTR - $17917195167.633087
# Found 1 results
# NA: HQH - $898121905.560042
# No results found for that keyword
# NA: RADCQ - $839610.375000
# Found 1 results
# NA: UHS - $14279598279.799999
# Found 2 results
# NA: CBRE - $34369348852.320000
# Found 1 results
# NA: LZAGY - $47774761943.014778
# Found 1 results
# NA: TPVG - $326848687.989195
# Found 10 results
# NA: PI - $4282914339.519402
# Found 1 results
# NA: HQL - $419146672.735848
# Found 1 results
# NA: THQ - $901418700.000000
# Found 1 results
# NA: PNTG - $896266214.000000
# Found 1 results
# NA: SLAB - $3668691432.111221
# Found 2 results
# NA: ECL - $67673664675.000000
# No results found for that keyword
# NA: PAIYY - $9872992.810778
# Found 1 results
# NA: EXLS - $5331220029.944403
# Found 1 results
# NA: THW - $503064842.444436
# Found 3 results
# NA: DVA - $11889489000.000000
# Found 1 results
# NA: IHF - $775877000.000000
# Found 1 results
# NA: NHC - $2034996583.454471
# No results found for that keyword
# NA: AHPIQ - $401.354000
# Found 1 results
# NA: AMED - $3212998781.000000
# Found 1 results
# NA: KEY-I - $15252068270.574306
# Found 2 results
# NA: NVS - $243144496677.073181
# Found 1 results
# NA: RHE-A - $3861959.000000
# Found 1 results
# NA: SIEGY - $142523549396.052887
# Found 1 results
# NA: PHR - $1423468039.109713
# Found 2 results
# NA: TFIN - $2020492776.000000
# Found 1 results
# NA: LLESY - $2785563821.046914
# Found 1 results
# NA: EHC - $9361217686.222284
# Found 4 results
# NA: AMN - $2537453016.000000
# Found 1 results
# NA: PSCH - $200112000.000000
# Found 1 results
# NA: HRZN - $442129915.000000
# Found 3 results
# NA: RVP - $33829036.000000
# Found 1 results
# NA: LIVN - $2632587156.983217
# Found 1 results
# NA: RSPH - $953109200.000000
# Found 2 results
# NA: BKD - $1472689190.000000
# Found 1 results
# NA: SBRA - $3744447800.000000
# Found 1 results
# NA: KURE - $38096425.857000
# Found 1 results
# NA: ZBH - $22838937297.104763
# Found 2 results
# NA: HCA - $94319595150.000000
# Found 2 results
# NA: LOB - $1930082356.000000
# Found 1 results
# NA: BCPC - $5631582762.168699
# No results found for that keyword
# NA: KLDO - $4262.260000
# Found 1 results
# NA: KAOOY - $19983495840.150345
# Found 1 results
# NA: BZLFY - $14007317323.190462
# Found 1 results
# NA: NOVT - $6152599658.995226
# Found 3 results
# NA: OSIS - $2456632657.621464
# Found 2 results
# NA: GDV - $2088999453.500000
# Found 1 results
# NA: XHE - $233200275.000000
# Found 1 results
# NA: SNOA - $6841584.000000
# Found 9 results
# NA: SEM - $5146666560.000000
# Found 1 results
# NA: HCAT - $421804630.982363
# Found 1 results
# NA: TCMD - $295126524.000000
# No results found for that keyword
# NA: EBIXQ - $61802.800000
# Found 1 results
# NA: SGRY - $3901799517.924911
# Found 1 results
# NA: SKHHY - $8422404898.811746
# Found 5 results
# NA: MOH - $19796838104.990807
# Found 2 results
# NA: CNC - $40041404876.583481
# Found 2 results
# NA: EVH - $2597363291.197797
# Found 1 results
# NA: GMRE-A - $679543498.782699
# Found 1 results
# NA: CMPGY - $52576623586.882065
# Found 3 results
# NA: JSM - $235200000.000000
# Found 3 results
# NA: LINC - $426691138.833445
# Found 1 results
# NA: RWR - $1486837295.970000
# Found 1 results
# NA: NSIT - $6666460043.623153
# Found 2 results
# NA: JBL - $12399276333.751289
# Found 1 results
# NA: SOMLY - $14350488767.095688
# Found 3 results
# NA: III - $160595820.000000
# Found 2 results
# NA: VTR - $22868747414.257210
# Found 10 results
# NA: DX - $906653860.800000
# Found 1 results
# NA: JRVR - $306010722.000000
# Found 1 results
# NA: SLGN - $5561382743.373896
# Found 1 results
# NA: TFX - $10952296552.000000
# Found 2 results
# NA: PBH - $3485696718.049991
# Found 2 results
# NA: CURE - $202401012.000000
# Found 3 results
# NA: SWK - $15843381839.999998
# Found 1 results
# NA: CHCT - $589622414.366507
# Found 1 results
# NA: CIX - $322867836.000000
# Found 1 results
# NA: CAH - $24831655650.000000
# Found 10 results
# NA: PG - $387771002000.000000
# Found 1 results
# NA: PLXS - $3382941056.000000
# Found 1 results
# NA: GMED - $9373656155.096815
# Found 2 results
# NA: NEOG - $3676222145.679382
# Found 2 results
# NA: SSY - $5914808.060000
# Found 1 results
# NA: HSTM - $902208584.999995
# Found 1 results
# NA: MDT - $102684181600.000000
# Found 1 results
# NA: HOCPY - $43982364612.448944
# Found 1 results
# NA: RCMT - $148013742.300000
# Found 1 results
# NA: VIAV - $1697725371.706897
# Found 1 results
# NA: TENB - $4979380520.000000
# Found 1 results
# NA: ARMK - $8799712898.514030
# Found 1 results
# NA: CDW - $28823667070.000000
# Found 1 results
# NA: RELL - $163549802.410000
# Found 1 results
# NA: OPRX - $192289885.213106
# Found 1 results
# NA: GKOS - $5814425086.192245
# Found 3 results
# NA: RHE - $3898927.503000
# Found 1 results
# NA: RHHBY - $264588183236.199921
# Found 1 results
# NA: TDOC - $1508486659.614080
# Found 1 results
# NA: XHS - $86451200.000000
# Found 1 results
# NA: FCBC - $801681457.457812
# Found 1 results
# NA: CBZ - $3553200924.179469
# Found 2 results
# NA: PFE - $173341069569.385132
# Found 4 results
# NA: HUM - $42918841170.000000
# Found 1 results
# NA: WBS - $8066748480.000000
# Found 1 results
# NA: RELX - $86134765148.639313
# Found 1 results
# NA: XRAY - $5588388365.000000
# Found 1 results
# NA: NMFC - $1336818320.160400
# Found 1 results
# NA: AVY - $17190901094.000000
# Found 1 results
# NA: ACHC - $6802094584.093177
# Found 1 results
# NA: WST - $21767195204.000000
# Found 1 results
# NA: UTMD - $243426385.700000
# Found 2 results
# NA: WBA - $10052838243.586763
# Found 1 results
# NA: NAII - $35468976.400000
# Found 3 results
# NA: CBU - $3119833344.000000
# Found 1 results
# NA: ITOCY - $76553194569.477142
# Found 3 results
# NA: PHG - $26332486439.721134
# Found 1 results
# NA: IRTC - $2675332449.000000
# Found 1 results
# NA: CSWC - $1176295785.363184
# Found 5 results
# NA: KEY - $14525218400.000000
# Found 1 results
# NA: VEEV - $30630402907.200001
# Found 2 results
# NA: TAK - $45193635781.685883
# Found 1 results
# NA: CYH - $723481408.000000
# Found 1 results
# NA: VHT - $18243167391.643250
# Found 1 results
# NA: OPK - $954879040.000000
# Found 1 results
# NA: BDX - $66730150343.605515
# Found 3 results
# NA: LLY - $788057164985.034058
# Found 2 results
# NA: MRK - $287511927150.000000
# Found 1 results
# NA: SNY - $130222725120.341248
# Found 5 results
# NA: AMS - $19307133.000000
# Found 3 results
# NA: GHY - $505406072.610000
# No results found for that keyword
# NA: GENN - $123720.735600
# Found 10 results
# NA: CI - $94385012208.263992
# Found 3 results
# NA: CVS - $74881747235.054871
# Found 1 results
# NA: IXJ - $4125693000.000000
# Found 1 results
# NA: KEQU - $155355817.517070
# Found 1 results
# NA: MCHX - $74694820.032700
# Found 1 results
# NA: MMM - $69012596250.000000
# Found 1 results
# NA: SBSI - $1014375044.500000
# Found 1 results
# NA: PRGO - $3831967478.113913
# Found 2 results
# NA: TPC - $1232903263.360000
# Found 1 results
# NA: IDXX - $39552722394.985558
# Found 1 results
# NA: TBBK - $2603246763.000000
# Found 3 results
# NA: ELV - $122375517640.000000
# Found 1 results
# NA: XLV - $40915628354.820000
# Found 5 results
# NA: THC - $14756970966.945414
# Found 10 results
# NA: TU - $24112140000.000000
# Found 3 results
# NA: MMS - $5549504520.000000
# Found 1 results
# NA: LUNA - $101536336.590000
# Found 3 results
# NA: REZ - $654689500.000000
# Found 1 results
# NA: IQV - $45233187500.000000
# Found 1 results
# NA: VMD - $271745366.990293
# Found 1 results
# NA: MLKN - $2146656642.000000
# Found 1 results
# NA: EGHT - $373012145.000000
# Found 10 results
# NA: CHE - $8803577917.246923
# Found 1 results
# NA: HOLX - $19136914000.000000
# No results found for that keyword
# NA: ALYAF - $122979502.920000
# Found 1 results
# NA: TKOMY - $72195752853.285355
# Found 1 results
# NA: CCOJY - $2926425980.396225
# Found 1 results
# NA: LXFR - $342406227.611285
# Found 1 results
# NA: TMO - $236664110388.970093
# Found 1 results
# NA: UHT - $586598993.000000
# Found 1 results
# NA: ARCC - $13175078930.931236
# Found 1 results
# NA: UMBF - $4755964900.288693
# Found 1 results
# NA: UNH - $524656281304.250488
# Found 1 results
# NA: LTC - $1536982542.000000
# Found 7 results
# NA: DOC - $30504462019.315243
# Found 1 results
# NA: TEVA - $19880629582.282143
# Found 1 results
# NA: PRPH - $59221664.582548
# Found 1 results
# NA: AGYS - $3123602191.783910
# Found 2 results
# NA: GMRE - $674196872.973465
# Found 2 results
# NA: BRC - $3364457150.270665
# Found 2 results
# NA: ABT - $191394508917.894592
# Found 1 results
# NA: DLHC - $150157095.000000
# Found 1 results
# NA: INFU - $142020485.230000
# Found 1 results
# NA: RLI - $6786433935.000000
# Found 1 results
# NA: IYH - $3392076000.000000
# Found 1 results
# NA: SRDX - $590446345.652187
# Found 1 results
# NA: SEIC - $8724912810.000000
# Found 1 results
# NA: OBDC - $6033066840.000000
# Found 1 results
# NA: PHAT - $684569164.000000
# Found 1 results
# NA: MTNB - $40453043.343750
# Found 1 results
# NA: BLRX - $60948797.330792
# Found 1 results
# NA: BMY - $97386159000.000000
# Found 1 results
# NA: ADMA - $2880229297.858303
# Found 1 results
# NA: APLS - $4364321360.000000
# Found 1 results
# NA: ALNY - $33381238799.999996
# Found 1 results
# NA: ITCI - $8264411000.000000
# Found 1 results
# NA: CSLLY - $96431663768.423157
# Found 1 results
# NA: ABBV - $335418177150.000000
# Found 1 results
# NA: DNLI - $3329920585.943823
# Found 4 results
# NA: EXEL - $7014335439.999999
# Found 1 results
# NA: DVAX - $1438489990.800000
# No results found for that keyword
# NA: SRNE - $4685889.809000
# Found 1 results
# NA: OMER - $294646257.000000
# Found 1 results
# NA: CYTK - $6864638720.000000
# Found 1 results
# NA: TBPH - $480982573.973297
# Found 1 results
# NA: DMAC - $144896503.113573
# Found 1 results
# NA: INCY - $12685538290.000000
# Found 1 results
# NA: TGTX - $3005598626.900000
# Found 1 results
# NA: RAPT - $105234052.500000
# Found 2 results
# NA: OCUL - $1274736470.000000
# Found 1 results
# NA: BTAI - $41662961.894375
# Found 2 results
# NA: GILD - $95451045330.476013
# Found 1 results
# NA: XBIT - $226604024.549222
# Found 2 results
# NA: SAGE - $592191182.488891
# Found 2 results
# NA: KURA - $1553322767.137917
# Found 1 results
# NA: PBYI - $168835800.000000
# Found 10 results
# NA: SPRO - $77200894.794326
# Found 1 results
# NA: MNKD - $1537223820.000000
# Found 1 results
# NA: XTLB - $15049213.908000
# Found 1 results
# NA: AXSM - $4106726657.141348
# Found 1 results
# NA: IFRX - $90680282.000000
# Found 1 results
# NA: EYEN - $74043053.708000
# Found 1 results
# NA: FATE - $577128240.000000
# Found 1 results
# NA: ARVN - $1841502429.000000
# No results found for that keyword
# NA: RVLPQ - $11140.600000
# Found 1 results
# NA: NKTR - $238305900.000000
# Found 1 results
# NA: ENTX - $62289951.764721
# Found 2 results
# NA: SLS - $66423941.225431
# Found 1 results
# NA: SRPT - $13549986730.000000
# Found 1 results
# NA: ALKS - $4452631642.319225
# Found 3 results
# NA: KOD - $148673904.569444
# Found 1 results
# NA: INSM - $12185912512.800001
# Found 1 results
# NA: ARWR - $3393150187.373196
# Found 1 results
# NA: MORF - $2854771993.142953
# Found 1 results
# NA: HALO - $7041434050.000000
# Found 2 results
# NA: ESPR - $417759943.363637
# No results found for that keyword
# NA: INFIQ - $9076.108100
# Found 1 results
# NA: CYCCP - $2399744.999997
# Found 1 results
# NA: FENC - $172311103.311214
# Found 1 results
# NA: APLT - $682061991.939157
# Found 1 results
# NA: AKBA - $276625295.965840
# Found 1 results
# NA: MGNX - $248341827.500000
# Found 1 results
# NA: QNCX - $32671591.466216
# Found 1 results
# NA: JAZZ - $7225689792.000000
# Found 1 results
# NA: SRRK - $730547556.000000
# Found 7 results
# NA: ADAP - $330867088.263158
# Found 1 results
# NA: YMAB - $516059795.011764
# Found 1 results
# NA: CPRX - $2007956399.009900
# Found 4 results
# NA: LAB - $505625303.372845
# Found 1 results
# NA: REGN - $121034265088.545166
# Found 1 results
# NA: ALEC - $561922218.000000
# Found 3 results
# NA: MIST - $74577440.000000
# Found 1 results
# NA: CUE - $38909775.670000
# Found 1 results
# NA: AMGN - $179810329825.000000
# Found 1 results
# NA: ASND - $7695027209.709020
# Found 1 results
# NA: AZN - $250627813026.012085
# Found 1 results
# NA: CLLS - $156089853.360000
# Found 1 results
# NA: SWTX - $2670815363.499025
# No results found for that keyword
# NA: SNNAQ - $31.000000
# Found 1 results
# NA: GERN - $2869399514.100000
# Found 1 results
# NA: MNOV - $65721971.000000
# Found 7 results
# NA: AIM - $20054981.700000
# Found 1 results
# NA: LQDA - $914673585.345750
# Found 1 results
# NA: AUTL - $1207804036.298509
# Found 1 results
# NA: VERU - $130428144.000000
# Found 1 results
# NA: EBS - $586031408.460000
# Found 1 results
# NA: BCRX - $1482819437.839283
# Found 1 results
# NA: AVXL - $563042120.000000
# Found 1 results
# NA: CMRX - $78435125.490000
# Found 1 results
# NA: LGND - $1881877212.000000
# Found 1 results
# NA: AMRN - $263780837.743590
# Found 1 results
# NA: PTGX - $2250482296.559293
# Found 1 results
# NA: ALIM - $293471046.000000
# Found 1 results
# NA: CDMO - $673641754.500000
# Found 1 results
# NA: PTCT - $2529460464.000000
# Found 1 results
# NA: GNFT - $225939869.691211
# Found 1 results
# NA: ZLAB - $1853266713.559071
# Found 1 results
# NA: XAIR - $25474944.000000
# Found 1 results
# NA: IPHA - $187906771.184834
# Found 1 results
# NA: NXTC - $44757280.000000
# Found 1 results
# NA: BGNE - $18073357714.569103
# Found 1 results
# NA: ACIU - $399767270.960880
# Found 1 results
# NA: VKTX - $6177996363.571109
# Found 1 results
# NA: CLSD - $83698874.482758
# Found 1 results
# NA: GTHX - $221411729.000000
# Found 1 results
# NA: CRVS - $162633380.000000
# Found 1 results
# NA: AGIO - $2526398500.000000
# Found 1 results
# NA: FULC - $555777805.326290
# Found 1 results
# NA: VRNA - $1836096721.278750
# Found 1 results
# NA: ARDX - $1304655752.000000
# Found 1 results
# NA: LXRX - $724792019.617777
# Found 1 results
# NA: ETNB - $933664170.360261
# Found 1 results
# NA: MIRM - $1907001892.415270
# Found 1 results
# NA: PRQR - $152700173.939222
# Found 5 results
# NA: RARE - $4019010260.772984
# Found 1 results
# NA: ABIO - $42505928.990000
# Found 1 results
# NA: ACRS - $95494832.000000
# Found 1 results
# NA: TRVI - $216235757.000000
# No results found for that keyword
# NA: NYMXF - $27379.500000
# Found 1 results
# NA: SGMO - $151362684.366667
# Found 1 results
# NA: VCEL - $2319031766.446539
# Found 1 results
# NA: MTNB - $40453043.343750
# Found 1 results
# NA: CSBR - $65114302.000000
# Found 1 results
# NA: PRTA - $1213899310.252923
# Found 1 results
# NA: BLRX - $60948797.330792
# Found 1 results
# NA: BMY - $97376022000.000000
# Found 1 results
# NA: ADMA - $2881388343.853416
# No results found for that keyword
# NA: GRTX - $6586892.000000
# Found 1 results
# NA: ALNY - $33380606339.999996
# Found 3 results
# NA: ALLO - $585640271.277777
# Found 1 results
# NA: KPTI - $121849524.800000
# Found 1 results
# NA: MRUS - $3554109625.500000
# Found 1 results
# NA: NVZMY - $29461137526.751640
# Found 1 results
# NA: ITCI - $8264411000.000000
# Found 1 results
# NA: RYTM - $2899871632.056418
# Found 10 results
# NA: EQ - $24861684.960000
# Found 1 results
# NA: MCRB - $193853440.000000
# Found 1 results
# NA: CSLLY - $96431663768.423157
# Found 1 results
# NA: EXAS - $10529281800.000000
# Found 1 results
# NA: FBIOP - $41632440.075882
# Found 1 results
# NA: IGC - $34130437.443409
# Found 1 results
# NA: IONS - $7309216114.396846
# Found 2 results
# NA: AKRO - $1879870136.370359
# Found 1 results
# NA: ILMN - $19483983373.419891
# Found 1 results
# NA: XNCR - $1236335130.000000
# Found 2 results
# NA: CAPR - $123440098.000000
# Found 1 results
# NA: GALT - $147601814.450000
# Found 1 results
# NA: URGN - $664277950.000000
# Found 1 results
# NA: DNLI - $3329920585.943823
# Found 4 results
# NA: EXEL - $7014335439.999999
# Found 1 results
# NA: BIIB - $30279080105.000000
# Found 1 results
# NA: WVE - $782003638.085365
# Found 1 results
# NA: DVAX - $1437194160.000000
# No results found for that keyword
# NA: SRNE - $4685889.809000
# Found 1 results
# NA: OMER - $294646257.000000
# Found 1 results
# NA: CYTK - $6864638720.000000
# Found 1 results
# NA: BPMC - $6582601684.200717
# Found 1 results
# NA: AUPH - $823076452.230445
# Found 1 results
# NA: NBIX - $15354724558.444736
# Found 2 results
# NA: ENZ - $57632624.000000
# Found 1 results
# NA: DMAC - $144896503.113573
# Found 2 results
# NA: SVA - $464938729.000000
# Found 1 results
# NA: INCY - $12685538290.000000
# Found 1 results
# NA: CHRS - $165779070.000000
# Found 1 results
# NA: VYGR - $478228748.369099
# Found 1 results
# NA: KMDA - $314959712.000000
# Found 2 results
# NA: CVM - $66042899.070797
# Found 1 results
# NA: ARGX - $31167326467.500000
# Found 1 results
# NA: KZR - $46221608.860000
# Found 1 results
# NA: TGTX - $3005598626.900000
# Found 1 results
# NA: RAPT - $105583087.500000
# Found 10 results
# NA: ALT - $443847772.000000
# Found 1 results
# NA: BTAI - $41662961.894375
# Found 1 results
# NA: MEDP - $11871209256.000000
# Found 2 results
# NA: GILD - $95432357532.003693
# Found 1 results
# NA: XBIT - $226604024.549222
# Found 1 results
# NA: HQH - $898121905.560042
# Found 1 results
# NA: OCGN - $342023466.000000
# Found 2 results
# NA: KURA - $1553322767.137917
# Found 1 results
# NA: LZAGY - $47774761943.014778
# Found 1 results
# NA: MRSN - $224532868.977500
# Found 10 results
# NA: VIR - $1341541740.000000
# Found 1 results
# NA: GMAB - $18842721542.322010
# Found 1 results
# NA: PBYI - $168835800.000000
# Found 1 results
# NA: MBOT - $16114112.377600
# Found 1 results
# NA: HQL - $419146672.735848
# Found 1 results
# NA: FGEN - $52622277.676111
# Found 2 results
# NA: CARA - $19005377.600000
# Found 1 results
# NA: MNKD - $1535862240.000000
# Found 1 results
# NA: RGEN - $9222317295.000000
# Found 1 results
# NA: XTLB - $15049213.908000
# Found 1 results
# NA: IGMS - $580733033.137000
# Found 1 results
# NA: IMMP - $279036382.676744
# Found 1 results
# NA: IFRX - $90680282.000000
# Found 1 results
# NA: FATE - $577128240.000000
# Found 1 results
# NA: ORGS - $35824845.000000
# Found 1 results
# NA: ARVN - $1841502429.000000
# Found 1 results
# NA: NNVC - $25281960.000000
# Found 1 results
# NA: CRSP - $4745223428.000000
# Found 1 results
# NA: NKTR - $238305900.000000
# Found 1 results
# NA: TWST - $3110141959.404337
# Found 1 results
# NA: QURE - $378734175.101048
# Found 1 results
# NA: FOLD - $3021229800.000000
# Found 2 results
# NA: SLS - $66423941.225431
# Found 1 results
# NA: SRPT - $13549986730.000000
# Found 1 results
# NA: ALKS - $4455101667.268737
# Found 1 results
# NA: UTHR - $14478119945.000000
# Found 10 results
# NA: A - $41549684010.000000
# Found 3 results
# NA: KOD - $148673904.569444
# Found 1 results
# NA: ALDX - $223398520.000000
# Found 1 results
# NA: CODX - $36059432.825000
# Found 1 results
# NA: INSM - $12185912512.800001
# Found 1 results
# NA: ARWR - $3393150187.373196
# Found 1 results
# NA: MORF - $2854771993.142953
# Found 1 results
# NA: HALO - $7045557727.599999
# No results found for that keyword
# NA: GNCAQ - $5878.350000
# Found 1 results
# NA: LCTX - $185085284.800000
# Found 1 results
# NA: EDIT - $428459980.000000
# Found 1 results
# NA: RCUS - $1433419432.702013
# Found 2 results
# NA: ESPR - $417759943.363637
# Found 1 results
# NA: GRTS - $63422867.645666
# Found 1 results
# NA: MREO - $558260122.475320
# Found 1 results
# NA: XFOR - $130370269.400000
# Found 1 results
# NA: INMB - $157270311.373692
# Found 4 results
# NA: XBI - $7828343750.000000
# No results found for that keyword
# NA: INFIQ - $9076.108100
# Found 1 results
# NA: CYCCP - $2399744.999997
# Found 1 results
# NA: RCKT - $2087083103.850006
# Found 1 results
# NA: FENC - $172311103.311214
# Found 1 results
# NA: APLT - $682061991.939157
# Found 1 results
# NA: BNTX - $19343743056.950001
# Found 1 results
# NA: AKBA - $275619233.364964
# Found 1 results
# NA: MGNX - $248028660.000000
# Found 1 results
# NA: SNDX - $1902011298.000000
# Found 1 results
# NA: TXG - $2401359189.980000
# Found 1 results
# NA: QNCX - $32671591.466216
# Found 1 results
# NA: GLPG - $1775267874.000000
# Found 1 results
# NA: DYAI - $40054434.460992
# Found 1 results
# NA: SRRK - $730547556.000000
# Found 1 results
# NA: NVAX - $1778216660.000000
# Found 7 results
# NA: ADAP - $330867088.263158
# Found 1 results
# NA: CPRX - $2007956399.009900
# Found 1 results
# NA: EDAP - $181808517.100000
# Found 4 results
# NA: LAB - $505625303.372845
# Found 1 results
# NA: ABUS - $714295378.973615
# Found 1 results
# NA: CRL - $12576066438.000000
# Found 1 results
# NA: REGN - $121034265088.545166
# Found 1 results
# NA: PDSB - $119574518.000000
# Found 1 results
# NA: HBIO - $135066140.553125
# Found 1 results
# NA: ALEC - $561922218.000000
# Found 1 results
# NA: VCYT - $1752954933.000000
# Found 1 results
# NA: CTLT - $10778263900.000000
# Found 1 results
# NA: RDY - $13851597282.520115
# Found 1 results
# NA: PSNL - $167243063.866667
# Found 1 results
# NA: CUE - $38909775.670000
# Found 1 results
# NA: AMGN - $179737911100.000000
# Found 1 results
# NA: MDT - $102715725442.000000
# Found 1 results
# NA: MRNA - $36465669240.000000
# Found 1 results
# NA: ASND - $7695027209.709020
# Found 1 results
# NA: AZN - $250612237374.217529
# Found 1 results
# NA: CLLS - $156089853.360000
# Found 1 results
# NA: GLW - $34273335263.000004
# Found 1 results
# NA: RLMD - $109631926.581732
# Found 1 results
# NA: GERN - $2864832390.000000
# Found 2 results
# NA: FBT - $1173130335.180000
# Found 1 results
# NA: MNOV - $65721971.000000
# Found 7 results
# NA: AIM - $20054981.700000
# Found 1 results
# NA: ARMP - $101594473.000001
# Found 1 results
# NA: HRTX - $417233909.648654
# Found 1 results
# NA: VXRT - $148872405.000000
# Found 1 results
# NA: ANAB - $936155347.711941
# Found 1 results
# NA: AUTL - $1207804036.298509
# Found 1 results
# NA: EBS - $583757166.000000
# Found 1 results
# NA: BCYC - $1071996651.565000
# Found 1 results
# NA: NTLA - $2471700125.310941
# Found 1 results
# NA: BCRX - $1482819437.839283
# Found 1 results
# NA: CTMX - $106749578.000000
# Found 1 results
# NA: AVXL - $563042120.000000
# Found 5 results
# NA: ACAD - $3185460880.000000
# Found 9 results
# NA: TECH - $12893604699.999998
# Found 1 results
# NA: CMRX - $78435125.490000
# Found 1 results
# NA: ANIX - $104021125.000000
# Found 1 results
# NA: LGND - $1881877212.000000
# Found 1 results
# NA: VNDA - $324164531.000000
# Found 1 results
# NA: AMRN - $263780837.743590
# Found 1 results
# NA: PTGX - $2250482296.559293
# Found 1 results
# NA: ALIM - $293471046.000000
# Found 1 results
# NA: ICLR - $27232584298.040020
# Found 1 results
# NA: SLP - $789505349.286964
# No results found for that keyword
# NA: NAVB - $100084.000000
# Found 1 results
# NA: ATYR - $136986718.707070
# Found 1 results
# NA: CDMO - $673959660.000000
# Found 1 results
# NA: CGEN - $161602011.000000
# Found 1 results
# NA: PTCT - $2525625624.000000
# Found 1 results
# NA: GNFT - $225939869.691211
# Found 1 results
# NA: OPK - $958364000.000000
# Found 1 results
# NA: ZLAB - $1855768423.485582
# Found 10 results
# NA: MOR - $2815664573.400000
# Found 1 results
# NA: VRTX - $130258986891.370834
# Found 1 results
# NA: IPHA - $187906771.184834
# Found 1 results
# NA: PBE - $269577000.000000
# Found 1 results
# NA: ONCY - $79617061.000000
# Found 1 results
# NA: NXTC - $44757280.000000
# Found 1 results
# NA: MGTX - $314459324.489485
# Found 1 results
# NA: BGNE - $18073357714.569103
# Found 2 results
# NA: REPL - $685946856.000000
# Found 10 results
# NA: BLUE - $206233940.000000
# Found 1 results
# NA: RGNX - $665941120.000000
# Found 1 results
# NA: BCDAW - $None
# Found 1 results
# NA: DXR - $41936183.100000
# Found 1 results
# NA: RVNC - $357224317.564366
# Found 2 results
# NA: XENE - $3274218226.500000
# Found 1 results
# NA: NTRA - $12775196090.000000
# Found 1 results
# NA: VKTX - $6186860059.932044
# Found 3 results
# NA: CABA - $326349290.762588
# Found 1 results
# NA: PACB - $543350220.000000
# Found 1 results
# NA: STOK - $769822739.000000
# Found 1 results
# NA: IRWD - $1058654446.262251
# Found 1 results
# NA: MYGN - $2490780160.000000
# Found 1 results
# NA: CLDX - $2523714821.350561
# Found 1 results
# NA: IQV - $45247771500.000000
# Found 1 results
# NA: BMRN - $16215752000.000002
# Found 1 results
# NA: SVRA - $752294700.000000
# Found 1 results
# NA: CDXS - $249844461.600000
# Found 2 results
# NA: IBB - $7954927499.999999
# Found 1 results
# NA: GLYC - $13950096.160000
# Found 1 results
# NA: IOVA - $2382777995.000000
# Found 1 results
# NA: AGIO - $2529804880.000000
# Found 1 results
# NA: BCLI - $26508762.681818
# Found 3 results
# NA: XOMA - $293335782.820000
# Found 2 results
# NA: BIB - $95526000.000000
# Found 7 results
# NA: DOC - $30497463978.016933
# Found 1 results
# NA: ARDX - $1302082005.000000
# Found 1 results
# NA: BBP - $21952250.880000
# Found 1 results
# NA: LXRX - $724792019.617777
# Found 1 results
# NA: PRQR - $152700173.939222
# Found 5 results
# NA: RARE - $4019010260.772984
# Found 1 results
# NA: ABIO - $42505928.990000
# Found 2 results
# NA: ENTA - $318855867.000000
# Found 1 results
# NA: IYH - $3392327920.000000
# Found 1 results
# NA: PHAT - $684569164.000000
# Found 3 results
# NA: SCL - $1864518569.260937
# Found 1 results
# NA: VRCA - $268731333.500000
# Found 1 results
# NA: MCK - $81007113720.000000
# Found 1 results
# NA: MTNB - $40453043.343750
# Found 1 results
# NA: CSBR - $65114302.000000
# Found 1 results
# NA: BLRX - $60948797.330792
# Found 1 results
# NA: BMY - $97406433000.000000
# Found 1 results
# NA: ADMA - $2879070251.863189
# Found 1 results
# NA: APLS - $4354612080.000000
# Found 1 results
# NA: CRMD - $248416036.000000
# No results found for that keyword
# NA: GRTX - $6586892.000000
# Found 1 results
# NA: ALNY - $33380606339.999996
# Found 1 results
# NA: KPTI - $121513061.600000
# Found 1 results
# NA: ITCI - $8264411000.000000
# Found 2 results
# NA: NVO - $595551691589.763794
# Found 1 results
# NA: CPIX - $20861106.146854
# Found 1 results
# NA: CSLLY - $96431663768.423157
# Found 1 results
# NA: FBIOP - $41632440.075882
# Found 1 results
# NA: IONS - $7307026633.783446
# Found 4 results
# NA: PSN - $9506924399.693703
# Found 1 results
# NA: ABBV - $335594764150.000000
# Found 1 results
# NA: ILMN - $19450530372.778748
# Found 1 results
# NA: BHC - $2241325368.050333
# Found 10 results
# NA: COR - $48231482640.000000
# Found 1 results
# NA: AMRX - $2222289778.836564
# Found 1 results
# NA: URGN - $664277950.000000
# Found 1 results
# NA: DNLI - $3330633631.037172
# Found 4 results
# NA: EXEL - $7014335439.999999
# Found 1 results
# NA: DVAX - $1437848620.000000
# No results found for that keyword
# NA: SRNE - $4685889.809000
# Found 1 results
# NA: OMER - $294646257.000000
# Found 1 results
# NA: MLAB - $595602919.892440
# Found 1 results
# NA: CYTK - $6856435840.000000
# Found 1 results
# NA: AUPH - $823791549.061227
# Found 1 results
# NA: TBPH - $480982573.973297
# Found 1 results
# NA: NBIX - $15354724558.444736
# Found 2 results
# NA: ENZ - $57632624.000000
# Found 1 results
# NA: OFLX - $506432150.551025
# Found 1 results
# NA: DMAC - $144896503.113573
# Found 1 results
# NA: INCY - $12685538290.000000
# Found 1 results
# NA: KMDA - $314959712.000000
# Found 1 results
# NA: XPH - $203596572.200000
# Found 1 results
# NA: SCPH - $174503346.998010
# Found 1 results
# NA: TGTX - $3004346828.600000
# Found 1 results
# NA: RAPT - $105583087.500000
# Found 1 results
# NA: HWKN - $2476350522.000000
# Found 1 results
# NA: BIO.B - $8392854846.300000
# Found 2 results
# NA: OCUL - $1270740333.800000
# Found 1 results
# NA: BTAI - $41662961.894375
# Found 1 results
# NA: MEDP - $11871209256.000000
# Found 2 results
# NA: GILD - $95519567258.207886
# Found 1 results
# NA: XBIT - $226604024.549222
# Found 2 results
# NA: SAGE - $592191182.488891
# Found 2 results
# NA: KURA - $1553322767.137917
# Found 1 results
# NA: LZAGY - $47774761943.014778
# Found 1 results
# NA: ATOS - $165999791.466667
# Found 1 results
# NA: PBYI - $168835800.000000
# Found 1 results
# NA: HQL - $419146672.735848
# Found 1 results
# NA: SQM - $10443745877.471525
# Found 1 results
# NA: DRIO - $32317164.000000
# Found 2 results
# NA: ECL - $67595846850.000000
# Found 10 results
# NA: SPRO - $77200894.794326
# Found 2 results
# NA: CARA - $19005377.600000
# Found 1 results
# NA: MNKD - $1539946980.000000
# Found 1 results
# NA: RGEN - $9222317295.000000
# Found 2 results
# NA: NVS - $243166244843.144470
# Found 1 results
# NA: ZTS - $82828971382.949875
# Found 1 results
# NA: XTLB - $15049213.908000
# Found 1 results
# NA: IGMS - $580733033.137000
# Found 2 results
# NA: IHE - $669678750.000000
# Found 1 results
# NA: PPH - $633048065.100000
# Found 1 results
# NA: AXSM - $4106726657.141348
# Found 1 results
# NA: HYPMY - $3119197110.692912
# Found 1 results
# NA: IFRX - $90680282.000000
# Found 2 results
# NA: CORT - $3951382557.569819
# Found 1 results
# NA: EYEN - $74043053.708000
# Found 1 results
# NA: FATE - $577128240.000000
# Found 1 results
# NA: SRCL - $5440218900.000000
# Found 1 results
# NA: ARVN - $1841160269.500000
# No results found for that keyword
# NA: RVLPQ - $11140.600000
# Found 1 results
# NA: NKTR - $238305900.000000
# Found 1 results
# NA: ENTX - $62289951.764721
# Found 2 results
# NA: SLS - $66423941.225431
# Found 1 results
# NA: SRPT - $13593940297.000000
# Found 1 results
# NA: ALKS - $4455925008.918574
# Found 3 results
# NA: KOD - $148673904.569444
# Found 1 results
# NA: FTXH - $18700557.540000
# Found 1 results
# NA: KALV - $600435888.899789
# Found 1 results
# NA: INSM - $12172434019.200001
# Found 1 results
# NA: ARWR - $3389424180.578862
# Found 1 results
# NA: MORF - $2854520869.638982
# Found 1 results
# NA: HALO - $7040797680.000000
# Found 1 results
# NA: PCRX - $950005901.000000
# Found 1 results
# NA: EDIT - $428459980.000000
# Found 1 results
# NA: RCUS - $1433419432.702013
# Found 2 results
# NA: ESPR - $416812641.904762
# No results found for that keyword
# NA: INFIQ - $9076.108100
# Found 1 results
# NA: CYCCP - $2399744.999997
# Found 3 results
# NA: STRO - $310818473.047857
# Found 1 results
# NA: FENC - $172311103.311214
# Found 1 results
# NA: APLT - $682061991.939157
# Found 1 results
# NA: GRFS - $6053534699.713551
# Found 1 results
# NA: AKBA - $275619233.364964
# Found 1 results
# NA: MGNX - $248028660.000000
# Found 1 results
# NA: QNCX - $32671591.466216
# Found 1 results
# NA: SOMLY - $14350488767.095688
# Found 1 results
# NA: GLPG - $1775267874.000000
# Found 1 results
# NA: JAZZ - $7215599808.000000
# Found 1 results
# NA: SRRK - $728952474.000000
# Found 1 results
# NA: SLGN - $5561382743.373896
# Found 7 results
# NA: ADAP - $330867088.263158
# Found 1 results
# NA: SUPN - $1628888509.000000
# Found 1 results
# NA: YMAB - $516059795.011764
# Found 1 results
# NA: CPRX - $2006775248.186953
# Found 2 results
# NA: PBH - $3485696718.049991
# Found 4 results
# NA: LAB - $503810238.181250
# Found 1 results
# NA: JAPAY - $55770365939.605141
# Found 10 results
# NA: BIO - $9526081532.700319
# Found 1 results
# NA: CRL - $12576066438.000000
# Found 1 results
# NA: REGN - $120922996057.980621
# Found 1 results
# NA: CAH - $24824348640.000000
# Found 1 results
# NA: ALEC - $561922218.000000
# Found 1 results
# NA: AQST - $330014661.710526
# Found 1 results
# NA: CTLT - $10778263900.000000
# Found 3 results
# NA: MIST - $74577440.000000
# Found 1 results
# NA: RDY - $13851597282.520115
# Found 1 results
# NA: OPTN - $150632560.000000
# Found 1 results
# NA: CUE - $38909775.670000
# Found 1 results
# NA: AMGN - $179952485100.000000
# Found 1 results
# NA: ASND - $7695027209.709020
# Found 1 results
# NA: AZN - $250565510418.833923
# Found 1 results
# NA: CLLS - $156089853.360000
# Found 1 results
# NA: SWTX - $2670815363.499025
# Found 1 results
# NA: OPRX - $192289885.213106
# Found 1 results
# NA: GKOS - $5813669573.577095
# No results found for that keyword
# NA: SNNAQ - $31.000000
# Found 1 results
# NA: RHHBY - $264392046703.037415
# Found 1 results
# NA: GERN - $2864832390.000000
# Found 1 results
# NA: ANIP - $1332908084.642136
# Found 2 results
# NA: MTD - $32351335224.000000
# Found 1 results
# NA: MNOV - $65721971.000000
# Found 7 results
# NA: AIM - $20003558.670000
# Found 2 results
# NA: PFE - $173375069125.364746
# Found 1 results
# NA: HRTX - $417233909.648654
# Found 1 results
# NA: LQDA - $913909447.012127
# Found 6 results
# NA: ATR - $9703330085.352497
# Found 3 results
# NA: SXT - $3225875917.318541
# Found 1 results
# NA: AUTL - $1207804036.298509
# Found 1 results
# NA: VERU - $130428144.000000
# Found 1 results
# NA: EBS - $582447118.500000
# Found 2 results
# NA: AMPH - $2074911860.000000
# Found 1 results
# NA: BCRX - $1479723781.392854
# Found 1 results
# NA: CNTG - $9680245.897500
# Found 1 results
# NA: AVXL - $563890075.000000
# Found 5 results
# NA: ACAD - $3185460880.000000
# Found 1 results
# NA: WST - $21760666460.000000
# Found 1 results
# NA: CRNX - $4154318659.151209
# Found 2 results
# NA: WBA - $10052838243.586763
# Found 1 results
# NA: CMRX - $78435125.490000
# Found 1 results
# NA: MDGL - $5971062962.674278
# Found 1 results
# NA: LGND - $1881877212.000000
# Found 1 results
# NA: AMRN - $263780837.743590
# Found 1 results
# NA: CDXC - $212264028.000000
# Found 1 results
# NA: IEX - $14789367252.000000
# Found 1 results
# NA: PTGX - $2249309253.923610
# Found 1 results
# NA: ALIM - $293471046.000000
# Found 1 results
# NA: ICLR - $27232584298.040020
# Found 1 results
# NA: SLP - $789505349.286964
# Found 2 results
# NA: TAK - $45177249401.779549
# Found 1 results
# NA: CDMO - $672052227.000000
# Found 1 results
# NA: PTCT - $2543265888.000000
# Found 1 results
# NA: GNFT - $225939869.691211
# Found 1 results
# NA: OPK - $959060992.000000
# Found 1 results
# NA: BDX - $66639113303.573311
# Found 3 results
# NA: LLY - $788617904182.001221
# Found 1 results
# NA: ZLAB - $1855768423.485582
# Found 2 results
# NA: MRK - $287347294500.000000
# Found 1 results
# NA: SNY - $130210077225.516052
# Found 10 results
# NA: MOR - $2815664573.400000
# Found 1 results
# NA: PJP - $285852000.000000
# Found 1 results
# NA: VRTX - $130258986891.370834
# Found 1 results
# NA: XAIR - $25474944.000000
# Found 1 results
# NA: IPHA - $187906771.184834
# Found 1 results
# NA: NXTC - $44757280.000000
# Found 10 results
# NA: ASH - $4802459965.120358
# Found 1 results
# NA: UGP - $4348383415.023633
# Found 1 results
# NA: BGNE - $18073357714.569103
# Found 1 results
# NA: ACIU - $399767270.960880
# Found 1 results
# NA: PRGO - $3834693886.849675
# Found 1 results
# NA: RFL - $35130335.587837
# Found 1 results
# NA: TRYIY - $8286856713.088123
# Found 1 results
# NA: ORMP - $100759733.270587
# Found 2 results
# NA: TPC - $1232903263.360000
# Found 1 results
# NA: VKTX - $6156391103.691332
# Found 1 results
# NA: CLSD - $83698874.482758
# Found 1 results
# NA: IDXX - $39468070385.349579
# Found 5 results
# NA: ALB - $11134552617.134792
# Found 10 results
# NA: YI - $98350424.349593
# Found 1 results
# NA: SNPHY - $4248412479.640178
# Found 1 results
# NA: DSNKY - $74318810475.535461
# Found 1 results
# NA: PILL - $16742227.610100
# Found 1 results
# NA: MYGN - $2490780160.000000
# Found 1 results
# NA: GTHX - $221150322.000000
# Found 1 results
# NA: IQV - $45197839530.000000
# Found 1 results
# NA: CRVS - $162633380.000000
# Found 1 results
# NA: BMRN - $16213853200.000000
# Found 1 results
# NA: SVRA - $752294700.000000
# Found 1 results
# NA: CDXS - $249844461.600000
# Found 2 results
# NA: IBB - $7951151000.000000
# Found 1 results
# NA: AGIO - $2520153470.000000
# Found 1 results
# NA: FULC - $555031961.704738
# Found 5 results
# NA: COLL - $1253651074.918339
# Found 1 results
# NA: VRNA - $1834069676.985000
# Found 2 results
# NA: HROW - $880656388.893708
# Found 2 results
# NA: BIB - $95526000.000000
# Found 5 results
# NA: ALC - $47056179757.448944
# Found 1 results
# NA: KNBWY - $12466879862.110176
# Found 7 results
# NA: DOC - $30511460060.613548
# Found 1 results
# NA: TEVA - $19817968572.137413
# Found 1 results
# NA: INGR - $8043131700.000000
# Found 1 results
# NA: ARDX - $1297402465.000000
# Found 1 results
# NA: LXRX - $724792019.617777
# Found 1 results
# NA: ETNB - $932522915.947598
# Found 1 results
# NA: MIRM - $1903231251.006639
# Found 2 results
# NA: ABT - $191342319904.373962
# Found 1 results
# NA: PRQR - $152700173.939222
# Found 5 results
# NA: RARE - $4015840337.187023
# Found 1 results
# NA: ABIO - $42505928.990000
# Found 10 results
# NA: NEO - $2213291057.150036
# Found 1 results
# NA: IYH - $3392327920.000000
# Found 1 results
# NA: ACRS - $95494832.000000
# Found 1 results
# NA: TRVI - $216235757.000000
# No results found for that keyword
# NA: NYMXF - $27379.500000

# %%
healthcare_df
# Out:
#                             name ticker        open        high         low  \
# 0                            WEX    WEX  183.315000  184.920000  180.500000
# 1                       Unicharm  UNICY    6.200000    6.454000    6.200000
# 2                         Sensus   SRTS    6.370000    6.440000    6.210000
# 3                       McKesson    MCK  620.980000  627.310000  620.625000
# 4    Streamline Health Solutions   STRM    0.500000    0.500000    0.465000
# ..                           ...    ...         ...         ...         ...
# 520                 Harrow, Inc.   HROW   25.810000   26.000000   24.760000
# 521                        Alcon    ALC   93.415000   94.190000   92.780000
# 522               Kirin Holdings  KNBWY   13.524500   13.690000   13.520000
# 523                    Ingredion   INGR  124.990000  125.465000  122.210000
# 524                  NeoGenomics    NEO   17.730000   18.010000   17.060000
#
#             volume overnight_volume   bounds market_date  \
# 0     97964.000000         0.000000  regular  2024-08-01
# 1     33153.000000         0.000000  regular  2024-08-01
# 2     96938.000000         0.000000  regular  2024-08-01
# 3    220559.000000         0.000000  regular  2024-08-01
# 4     53187.000000         0.000000  regular  2024-08-01
# ..             ...              ...      ...         ...
# 520  121472.000000         0.000000  regular  2024-08-01
# 521  191343.000000         0.000000  regular  2024-08-01
# 522    4372.000000         0.000000  regular  2024-08-01
# 523   70928.000000         0.000000  regular  2024-08-01
# 524  251331.000000         0.000000  regular  2024-08-01
#
#     average_volume_2_weeks  ... headquarters_state                 sector  \
# 0            478751.700000  ...              Maine    Commercial Services
# 1            113705.900000  ...              Tokyo  Consumer Non-Durables
# 2            181794.400000  ...            Florida      Health Technology
# 3            654055.900000  ...              Texas  Distribution Services
# 4             24158.100000  ...            Georgia    Technology Services
# ..                     ...  ...                ...                    ...
# 520          311144.200000  ...          Tennessee      Health Technology
# 521          904058.600000  ...    Geneve (Geneva)      Health Technology
# 522           44801.700000  ...              Tokyo  Consumer Non-Durables
# 523          290203.300000  ...           Illinois  Consumer Non-Durables
# 524         1221043.700000  ...            Florida        Health Services
#
#                               industry num_employees year_founded  \
# 0    Miscellaneous Commercial Services          7200         1983
# 1              Household/Personal Care         16223         1961
# 2                  Medical Specialties            35         2010
# 3                 Medical Distributors         51000         1833
# 4      Information Technology Services            77         1989
# ..                                 ...           ...          ...
# 520             Pharmaceuticals: Major           315         2006
# 521                Medical Specialties         25315         1945
# 522               Beverages: Alcoholic         30183         1907
# 523              Food: Specialty/Candy         11600         1906
# 524           Medical/Nursing Services          2100         1998
#
#     payable_date ex_dividend_date financial_status_indicator  \
# 0           None             None                        CA0
# 1     2024-03-18       2023-12-28                       None
# 2           None             None                        CC0
# 3     2024-07-01       2024-06-03                        CA0
# 4           None             None                        CC4
# ..           ...              ...                        ...
# 520         None             None                        CC0
# 521   2024-05-16       2024-05-14                        CA0
# 522   2024-04-05       2023-12-28                       None
# 523   2024-07-23       2024-07-01                        CA0
# 524         None             None                        CC0
#
#     financial_status_description symbol
# 0                                   WEX
# 1                           None  UNICY
# 2                                  SRTS
# 3                                   MCK
# 4                   Noncompliant   STRM
# ..                           ...    ...
# 520                                HROW
# 521                                 ALC
# 522                         None  KNBWY
# 523                                INGR
# 524                                 NEO
#
# [525 rows x 36 columns]

# %%
company_info = rs.find_instrument_data('MDRX')
company_info[0]
# Out:
# No results found for that keyword

# %%
stock_info = rs.stocks.get_fundamentals('PFE')
stock_info[0].keys()
# Out:
# [{'open': '30.738000',
#   'high': '30.810000',
#   'low': '29.910000',
#   'volume': '14833541.000000',
#   'overnight_volume': '0.000000',
#   'bounds': 'regular',
#   'market_date': '2024-08-01',
#   'average_volume_2_weeks': '42939487.400000',
#   'average_volume': '42939487.400000',
#   'average_volume_30_days': '35502187.772700',
#   'high_52_weeks': '37.186000',
#   'high_52_weeks_date': '2023-08-21',
#   'dividend_yield': '5.435490',
#   'float': '5664142033.120000',
#   'low_52_weeks': '25.200000',
#   'low_52_weeks_date': '2024-04-26',
#   'market_cap': '172942708105.157379',
#   'pb_ratio': '1.875450',
#   'pe_ratio': '-66.220000',
#   'shares_outstanding': '5666592663.268557',
#   'description': 'Pfizer Inc. is a research-based global biopharmaceutical company, which engages in the discovery, development, manufacture, marketing, sales and distribution of biopharmaceutical products worldwide. The firm works across developed and emerging markets to advance wellness, prevention, treatments and cures that challenge the most feared diseases. The company was founded by Charles Pfizer Sr. and Charles Erhart in 1849 and is headquartered in New York, NY.',
#   'instrument': 'https://api.robinhood.com/instruments/6ec6c70e-d686-4d73-b5a8-74fec96aca0e/',
#   'ceo': 'Albert Bourla',
#   'headquarters_city': 'New York',
#   'headquarters_state': 'New York',
#   'sector': 'Health Technology',
#   'industry': 'Pharmaceuticals: Major',
#   'num_employees': 88000,
#   'year_founded': 1849,
#   'payable_date': '2024-09-03',
#   'ex_dividend_date': '2024-07-26',
#   'financial_status_indicator': 'CA0',
#   'financial_status_description': '',
#   'symbol': 'PFE'}]

# %%
stock_info[0].keys()
# Out:
# dict_keys(['open', 'high', 'low', 'volume', 'overnight_volume', 'bounds', 'market_date', 'average_volume_2_weeks', 'average_volume', 'average_volume_30_days', 'high_52_weeks', 'high_52_weeks_date', 'dividend_yield', 'float', 'low_52_weeks', 'low_52_weeks_date', 'market_cap', 'pb_ratio', 'pe_ratio', 'shares_outstanding', 'description', 'instrument', 'ceo', 'headquarters_city', 'headquarters_state', 'sector', 'industry', 'num_employees', 'year_founded', 'payable_date', 'ex_dividend_date', 'financial_status_indicator', 'financial_status_description', 'symbol'])

# %%
# Out:
# [{'ask_price': '181.070000',
#   'ask_size': 8,
#   'venue_ask_time': '2024-08-01T15:34:25.879905662Z',
#   'bid_price': '180.580000',
#   'bid_size': 25,
#   'venue_bid_time': '2024-08-01T15:34:25.879905662Z',
#   'last_trade_price': '180.810000',
#   'venue_last_trade_time': '2024-08-01T15:34:07.713558246Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '183.450000',
#   'adjusted_previous_close': '183.450000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'WEX',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:25Z',
#   'instrument': 'https://api.robinhood.com/instruments/5ea7992b-e531-495d-a16c-7db8a7ec637d/',
#   'instrument_id': '5ea7992b-e531-495d-a16c-7db8a7ec637d',
#   'state': 'active'},
#  {'ask_price': '6.440000',
#   'ask_size': 2400,
#   'venue_ask_time': '2024-08-01T15:34:31.347Z',
#   'bid_price': '6.410000',
#   'bid_size': 2600,
#   'venue_bid_time': '2024-08-01T15:34:31.347Z',
#   'last_trade_price': '6.435000',
#   'venue_last_trade_time': '2024-08-01T15:23:02Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '6.730000',
#   'adjusted_previous_close': '6.730000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'UNICY',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/46e7f59e-7b20-4b37-8f54-6216553624c0/',
#   'instrument_id': '46e7f59e-7b20-4b37-8f54-6216553624c0',
#   'state': 'active'},
#  {'ask_price': '6.290000',
#   'ask_size': 81,
#   'venue_ask_time': '2024-08-01T15:34:28.455757027Z',
#   'bid_price': '6.220000',
#   'bid_size': 90,
#   'venue_bid_time': '2024-08-01T15:34:28.455757027Z',
#   'last_trade_price': '6.220000',
#   'venue_last_trade_time': '2024-08-01T15:34:28.407555205Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '6.370000',
#   'adjusted_previous_close': '6.370000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'SRTS',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:28Z',
#   'instrument': 'https://api.robinhood.com/instruments/49377a0e-2f9a-46f1-a293-b90df0dbb0dc/',
#   'instrument_id': '49377a0e-2f9a-46f1-a293-b90df0dbb0dc',
#   'state': 'active'},
#  {'ask_price': '626.000000',
#   'ask_size': 2,
#   'venue_ask_time': '2024-08-01T15:34:05.429584565Z',
#   'bid_price': '625.420000',
#   'bid_size': 3,
#   'venue_bid_time': '2024-08-01T15:34:05.429584565Z',
#   'last_trade_price': '625.525000',
#   'venue_last_trade_time': '2024-08-01T15:33:32.203752897Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '617.020000',
#   'adjusted_previous_close': '617.020000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'MCK',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:05Z',
#   'instrument': 'https://api.robinhood.com/instruments/ab56f82e-b48e-486f-b251-992e7323df82/',
#   'instrument_id': 'ab56f82e-b48e-486f-b251-992e7323df82',
#   'state': 'active'},
#  {'ask_price': '0.499900',
#   'ask_size': 200,
#   'venue_ask_time': '2024-08-01T15:26:56.053872153Z',
#   'bid_price': '0.490000',
#   'bid_size': 100,
#   'venue_bid_time': '2024-08-01T15:26:56.053872153Z',
#   'last_trade_price': '0.490000',
#   'venue_last_trade_time': '2024-08-01T14:49:58.123093612Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '0.516000',
#   'adjusted_previous_close': '0.516000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'STRM',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:26:56Z',
#   'instrument': 'https://api.robinhood.com/instruments/9957e212-15db-4530-9b9e-d1088eaa045c/',
#   'instrument_id': '9957e212-15db-4530-9b9e-d1088eaa045c',
#   'state': 'active'},
#  {'ask_price': '11.100000',
#   'ask_size': 209,
#   'venue_ask_time': '2024-08-01T15:02:06.592097279Z',
#   'bid_price': '10.650000',
#   'bid_size': 1000,
#   'venue_bid_time': '2024-08-01T15:02:06.592097279Z',
#   'last_trade_price': '10.840000',
#   'venue_last_trade_time': '2024-08-01T14:42:21.602041947Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '11.060000',
#   'adjusted_previous_close': '11.060000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'UG',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:02:06Z',
#   'instrument': 'https://api.robinhood.com/instruments/6444c8fc-337b-4d66-8221-b3851e9d4049/',
#   'instrument_id': '6444c8fc-337b-4d66-8221-b3851e9d4049',
#   'state': 'active'},
#  {'ask_price': '44.790000',
#   'ask_size': 200,
#   'venue_ask_time': '2024-08-01T15:34:31.474518937Z',
#   'bid_price': '44.670000',
#   'bid_size': 700,
#   'venue_bid_time': '2024-08-01T15:34:31.474518937Z',
#   'last_trade_price': '44.930000',
#   'venue_last_trade_time': '2024-08-01T14:57:09.326266287Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '44.920000',
#   'adjusted_previous_close': '44.920000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'PTH',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/5c1dca68-fe7f-4774-9b5a-ace2498c89ca/',
#   'instrument_id': '5c1dca68-fe7f-4774-9b5a-ace2498c89ca',
#   'state': 'active'},
#  {'ask_price': '26.910000',
#   'ask_size': 49,
#   'venue_ask_time': '2024-08-01T15:34:17.014006264Z',
#   'bid_price': '26.890000',
#   'bid_size': 562,
#   'venue_bid_time': '2024-08-01T15:34:17.014006264Z',
#   'last_trade_price': '26.900000',
#   'venue_last_trade_time': '2024-08-01T15:34:32.008554315Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '26.960000',
#   'adjusted_previous_close': '26.960000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'CTRE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:32Z',
#   'instrument': 'https://api.robinhood.com/instruments/89859139-01c4-4711-b890-29ccf50d0416/',
#   'instrument_id': '89859139-01c4-4711-b890-29ccf50d0416',
#   'state': 'active'},
#  {'ask_price': '54.500000',
#   'ask_size': 180,
#   'venue_ask_time': '2024-08-01T15:33:51.767809904Z',
#   'bid_price': '54.450000',
#   'bid_size': 50,
#   'venue_bid_time': '2024-08-01T15:33:51.767809904Z',
#   'last_trade_price': '54.480000',
#   'venue_last_trade_time': '2024-08-01T15:33:49.393533255Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '55.560000',
#   'adjusted_previous_close': '55.560000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'ABM',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:33:51Z',
#   'instrument': 'https://api.robinhood.com/instruments/a3e8ed07-9f4b-4747-b0a6-c5f7bb133ddd/',
#   'instrument_id': 'a3e8ed07-9f4b-4747-b0a6-c5f7bb133ddd',
#   'state': 'active'},
#  {'ask_price': '13.900000',
#   'ask_size': 1,
#   'venue_ask_time': '2024-08-01T15:34:29.05235681Z',
#   'bid_price': '13.880000',
#   'bid_size': 105,
#   'venue_bid_time': '2024-08-01T15:34:29.05235681Z',
#   'last_trade_price': '13.890000',
#   'venue_last_trade_time': '2024-08-01T15:34:25.483353258Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '14.470000',
#   'adjusted_previous_close': '14.470000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'HEAR',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:29Z',
#   'instrument': 'https://api.robinhood.com/instruments/804d0e81-ee8d-4af9-9c39-3886a153a210/',
#   'instrument_id': '804d0e81-ee8d-4af9-9c39-3886a153a210',
#   'state': 'active'},
#  {'ask_price': '125.460000',
#   'ask_size': 101,
#   'venue_ask_time': '2024-08-01T15:34:31.671330056Z',
#   'bid_price': '125.180000',
#   'bid_size': 300,
#   'venue_bid_time': '2024-08-01T15:34:31.671330056Z',
#   'last_trade_price': '125.200000',
#   'venue_last_trade_time': '2024-08-01T15:34:12.540788776Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '126.980000',
#   'adjusted_previous_close': '126.980000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'ICUI',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/5a964ac3-2b6f-41b0-877a-9e68b1ee61e1/',
#   'instrument_id': '5a964ac3-2b6f-41b0-877a-9e68b1ee61e1',
#   'state': 'active'},
#  {'ask_price': '5.990000',
#   'ask_size': 100,
#   'venue_ask_time': '2024-02-29T22:00:03.683Z',
#   'bid_price': '5.980000',
#   'bid_size': 100,
#   'venue_bid_time': '2024-02-29T22:00:03.683Z',
#   'last_trade_price': '9.700000',
#   'venue_last_trade_time': '2024-08-01T15:29:32Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '9.650000',
#   'adjusted_previous_close': '9.650000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'MDRX',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:29:32Z',
#   'instrument': 'https://api.robinhood.com/instruments/ea6bf532-d3ff-4094-9e6b-4fb473b2c702/',
#   'instrument_id': 'ea6bf532-d3ff-4094-9e6b-4fb473b2c702',
#   'state': 'unlisted'},
#  {'ask_price': '133.090000',
#   'ask_size': 265,
#   'venue_ask_time': '2024-08-01T15:34:30.973126147Z',
#   'bid_price': '133.050000',
#   'bid_size': 29,
#   'venue_bid_time': '2024-08-01T15:34:30.973126147Z',
#   'last_trade_price': '133.090000',
#   'venue_last_trade_time': '2024-08-01T15:34:27.810726034Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '132.630000',
#   'adjusted_previous_close': '132.630000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'NVO',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:30Z',
#   'instrument': 'https://api.robinhood.com/instruments/2e21c3b3-0015-4661-af59-e2d5741bf55d/',
#   'instrument_id': '2e21c3b3-0015-4661-af59-e2d5741bf55d',
#   'state': 'active'},
#  {'ask_price': '12.410000',
#   'ask_size': 653,
#   'venue_ask_time': '2024-08-01T15:34:15.54256009Z',
#   'bid_price': '12.380000',
#   'bid_size': 148,
#   'venue_bid_time': '2024-08-01T15:34:15.54256009Z',
#   'last_trade_price': '12.395000',
#   'venue_last_trade_time': '2024-08-01T15:32:19.498090413Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '13.100000',
#   'adjusted_previous_close': '13.100000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'PRA',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:15Z',
#   'instrument': 'https://api.robinhood.com/instruments/b70f8529-5b26-490c-8675-9ed05b6922bb/',
#   'instrument_id': 'b70f8529-5b26-490c-8675-9ed05b6922bb',
#   'state': 'active'},
#  {'ask_price': '17.520000',
#   'ask_size': 78,
#   'venue_ask_time': '2024-08-01T15:34:27.16814672Z',
#   'bid_price': '17.510000',
#   'bid_size': 102,
#   'venue_bid_time': '2024-08-01T15:34:27.16814672Z',
#   'last_trade_price': '17.520000',
#   'venue_last_trade_time': '2024-08-01T15:34:00.783796471Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '18.180000',
#   'adjusted_previous_close': '18.180000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'CAE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:27Z',
#   'instrument': 'https://api.robinhood.com/instruments/7fc2fd33-01ad-4dee-8bc7-0d1079207038/',
#   'instrument_id': '7fc2fd33-01ad-4dee-8bc7-0d1079207038',
#   'state': 'active'},
#  {'ask_price': '158.740000',
#   'ask_size': 10,
#   'venue_ask_time': '2024-08-01T15:34:31.524417773Z',
#   'bid_price': '158.700000',
#   'bid_size': 21,
#   'venue_bid_time': '2024-08-01T15:34:31.524417773Z',
#   'last_trade_price': '158.720000',
#   'venue_last_trade_time': '2024-08-01T15:34:26.345666454Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '157.850000',
#   'adjusted_previous_close': '157.850000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'JNJ',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/fd0c2695-e591-4c28-bdf7-068895ae3b14/',
#   'instrument_id': 'fd0c2695-e591-4c28-bdf7-068895ae3b14',
#   'state': 'active'},
#  {'ask_price': '44.510000',
#   'ask_size': 20,
#   'venue_ask_time': '2024-08-01T15:34:18.654709807Z',
#   'bid_price': '44.280000',
#   'bid_size': 38,
#   'venue_bid_time': '2024-08-01T15:34:18.654709807Z',
#   'last_trade_price': '44.375000',
#   'venue_last_trade_time': '2024-08-01T15:26:43.75538918Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '45.000000',
#   'adjusted_previous_close': '45.000000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'MBIN',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:18Z',
#   'instrument': 'https://api.robinhood.com/instruments/47303a7a-7f6b-46a4-bd9d-8fd6879cc129/',
#   'instrument_id': '47303a7a-7f6b-46a4-bd9d-8fd6879cc129',
#   'state': 'active'},
#  {'ask_price': '241.810000',
#   'ask_size': 9,
#   'venue_ask_time': '2024-08-01T15:34:02.909937342Z',
#   'bid_price': '241.720000',
#   'bid_size': 2,
#   'venue_bid_time': '2024-08-01T15:34:02.909937342Z',
#   'last_trade_price': '241.810000',
#   'venue_last_trade_time': '2024-08-01T15:34:03.698377245Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '237.880000',
#   'adjusted_previous_close': '237.880000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'COR',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:03Z',
#   'instrument': 'https://api.robinhood.com/instruments/2db426d6-099b-4406-a76f-547e00f4e35b/',
#   'instrument_id': '2db426d6-099b-4406-a76f-547e00f4e35b',
#   'state': 'active'},
#  {'ask_price': '109.900000',
#   'ask_size': 1100,
#   'venue_ask_time': '2024-08-01T15:33:44.049435244Z',
#   'bid_price': '109.570000',
#   'bid_size': 1100,
#   'venue_bid_time': '2024-08-01T15:33:44.049435244Z',
#   'last_trade_price': '109.415000',
#   'venue_last_trade_time': '2024-08-01T15:06:09.982999413Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '109.235100',
#   'adjusted_previous_close': '109.235100',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'FXH',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:33:44Z',
#   'instrument': 'https://api.robinhood.com/instruments/a87b4993-6af0-4312-addd-9f6f833001bd/',
#   'instrument_id': 'a87b4993-6af0-4312-addd-9f6f833001bd',
#   'state': 'active'},
#  {'ask_price': '88.770000',
#   'ask_size': 1,
#   'venue_ask_time': '2024-08-01T15:34:27.596361059Z',
#   'bid_price': '88.430000',
#   'bid_size': 22,
#   'venue_bid_time': '2024-08-01T15:34:27.596361059Z',
#   'last_trade_price': '88.870000',
#   'venue_last_trade_time': '2024-08-01T15:30:46.959540663Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '90.050000',
#   'adjusted_previous_close': '90.050000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'HAE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:27Z',
#   'instrument': 'https://api.robinhood.com/instruments/76e682f0-c738-4b03-b683-f9ca751c486f/',
#   'instrument_id': '76e682f0-c738-4b03-b683-f9ca751c486f',
#   'state': 'active'},
#  {'ask_price': '56.780000',
#   'ask_size': 1,
#   'venue_ask_time': '2024-08-01T15:34:31.895346457Z',
#   'bid_price': '56.700000',
#   'bid_size': 17,
#   'venue_bid_time': '2024-08-01T15:34:31.895346457Z',
#   'last_trade_price': '56.740000',
#   'venue_last_trade_time': '2024-08-01T15:33:27.910022988Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '59.110000',
#   'adjusted_previous_close': '59.110000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'HELE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/acad0b54-8d15-49a9-9cc7-8c5f1becb743/',
#   'instrument_id': 'acad0b54-8d15-49a9-9cc7-8c5f1becb743',
#   'state': 'active'},
#  {'ask_price': '71.960000',
#   'ask_size': 200,
#   'venue_ask_time': '2024-08-01T15:34:23.5695274Z',
#   'bid_price': '71.910000',
#   'bid_size': 118,
#   'venue_bid_time': '2024-08-01T15:34:23.5695274Z',
#   'last_trade_price': '71.950000',
#   'venue_last_trade_time': '2024-08-01T15:34:04.583299523Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '71.940000',
#   'adjusted_previous_close': '71.940000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'HSIC',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:23Z',
#   'instrument': 'https://api.robinhood.com/instruments/8ae6f221-9ec8-4e15-aedd-859f20088c8d/',
#   'instrument_id': '8ae6f221-9ec8-4e15-aedd-859f20088c8d',
#   'state': 'active'},
#  {'ask_price': '67.700000',
#   'ask_size': 3300,
#   'venue_ask_time': '2024-08-01T15:34:31.826Z',
#   'bid_price': '67.210000',
#   'bid_size': 400,
#   'venue_bid_time': '2024-08-01T15:34:31.826Z',
#   'last_trade_price': '67.203300',
#   'venue_last_trade_time': '2024-08-01T15:23:56Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '68.700000',
#   'adjusted_previous_close': '68.550000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'ONEXF',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/91427b8a-f297-453e-b61d-28455bc0573d/',
#   'instrument_id': '91427b8a-f297-453e-b61d-28455bc0573d',
#   'state': 'active'},
#  {'ask_price': '18.600000',
#   'ask_size': 600,
#   'venue_ask_time': '2024-08-01T15:34:32.116347418Z',
#   'bid_price': '18.580000',
#   'bid_size': 1100,
#   'venue_bid_time': '2024-08-01T15:34:32.116347418Z',
#   'last_trade_price': '18.585000',
#   'venue_last_trade_time': '2024-08-01T15:34:31.208374622Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '19.290000',
#   'adjusted_previous_close': '19.290000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'FMS',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:32Z',
#   'instrument': 'https://api.robinhood.com/instruments/d4528be4-734b-4c0c-b15b-269883a07d5d/',
#   'instrument_id': 'd4528be4-734b-4c0c-b15b-269883a07d5d',
#   'state': 'active'},
#  {'ask_price': '16.200000',
#   'ask_size': 208,
#   'venue_ask_time': '2024-08-01T15:34:21.027024944Z',
#   'bid_price': '16.180000',
#   'bid_size': 205,
#   'venue_bid_time': '2024-08-01T15:34:21.027024944Z',
#   'last_trade_price': '16.190000',
#   'venue_last_trade_time': '2024-08-01T15:34:18.897187157Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '16.420000',
#   'adjusted_previous_close': '16.420000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'OMI',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:21Z',
#   'instrument': 'https://api.robinhood.com/instruments/06706e77-79e9-491f-ba19-9b3344a652ed/',
#   'instrument_id': '06706e77-79e9-491f-ba19-9b3344a652ed',
#   'state': 'active'},
#  {'ask_price': '110.830000',
#   'ask_size': 1,
#   'venue_ask_time': '2024-08-01T15:34:32.117601146Z',
#   'bid_price': '109.580000',
#   'bid_size': 5,
#   'venue_bid_time': '2024-08-01T15:34:32.117601146Z',
#   'last_trade_price': '110.830000',
#   'venue_last_trade_time': '2024-08-01T15:23:55.946992992Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '114.520000',
#   'adjusted_previous_close': '114.520000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'MLAB',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:32Z',
#   'instrument': 'https://api.robinhood.com/instruments/a176b8e6-7472-4bd0-b828-8273072f8b62/',
#   'instrument_id': 'a176b8e6-7472-4bd0-b828-8273072f8b62',
#   'state': 'active'},
#  {'ask_price': '17.770000',
#   'ask_size': 241,
#   'venue_ask_time': '2024-08-01T15:34:29.380091056Z',
#   'bid_price': '17.700000',
#   'bid_size': 36,
#   'venue_bid_time': '2024-08-01T15:34:29.380091056Z',
#   'last_trade_price': '17.730000',
#   'venue_last_trade_time': '2024-08-01T15:34:15.427675914Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '18.240000',
#   'adjusted_previous_close': '18.240000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'CCRN',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:29Z',
#   'instrument': 'https://api.robinhood.com/instruments/e11899eb-21ae-4e16-9a6e-245a0a192e67/',
#   'instrument_id': 'e11899eb-21ae-4e16-9a6e-245a0a192e67',
#   'state': 'active'},
#  {'ask_price': '7.420000',
#   'ask_size': 2608,
#   'venue_ask_time': '2024-08-01T15:34:31.286Z',
#   'bid_price': '7.390000',
#   'bid_size': 100,
#   'venue_bid_time': '2024-08-01T15:34:31.286Z',
#   'last_trade_price': '7.400000',
#   'venue_last_trade_time': '2024-08-01T15:34:31.286Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '7.460000',
#   'adjusted_previous_close': '7.460000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'BAYRY',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/09f56105-7458-4a46-af95-58530c6b5c7c/',
#   'instrument_id': '09f56105-7458-4a46-af95-58530c6b5c7c',
#   'state': 'active'},
#  {'ask_price': '11.240000',
#   'ask_size': 430,
#   'venue_ask_time': '2024-08-01T15:34:29.153625185Z',
#   'bid_price': '11.220000',
#   'bid_size': 100,
#   'venue_bid_time': '2024-08-01T15:34:29.153625185Z',
#   'last_trade_price': '11.240000',
#   'venue_last_trade_time': '2024-08-01T15:34:15.966435608Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '11.930000',
#   'adjusted_previous_close': '11.930000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'RGP',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:29Z',
#   'instrument': 'https://api.robinhood.com/instruments/202eeccc-6c9b-483e-a977-6a8e102fd2a3/',
#   'instrument_id': '202eeccc-6c9b-483e-a977-6a8e102fd2a3',
#   'state': 'active'},
#  {'ask_price': '36.250000',
#   'ask_size': 357,
#   'venue_ask_time': '2024-08-01T15:34:25.124186158Z',
#   'bid_price': '36.230000',
#   'bid_size': 117,
#   'venue_bid_time': '2024-08-01T15:34:25.124186158Z',
#   'last_trade_price': '36.240000',
#   'venue_last_trade_time': '2024-08-01T15:34:20.90986883Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '36.400000',
#   'adjusted_previous_close': '36.400000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'OHI',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:25Z',
#   'instrument': 'https://api.robinhood.com/instruments/27e539a7-48ea-475d-858c-9cf5f6eb5e65/',
#   'instrument_id': '27e539a7-48ea-475d-858c-9cf5f6eb5e65',
#   'state': 'active'},
#  {'ask_price': '76.880000',
#   'ask_size': 181,
#   'venue_ask_time': '2024-08-01T15:34:02.908991426Z',
#   'bid_price': '76.660000',
#   'bid_size': 6,
#   'venue_bid_time': '2024-08-01T15:34:02.908991426Z',
#   'last_trade_price': '76.760000',
#   'venue_last_trade_time': '2024-08-01T15:27:55.372266995Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '78.410000',
#   'adjusted_previous_close': '78.410000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'ATGE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:02Z',
#   'instrument': 'https://api.robinhood.com/instruments/405634c9-f22a-49cd-bbef-01b8b8204c6f/',
#   'instrument_id': '405634c9-f22a-49cd-bbef-01b8b8204c6f',
#   'state': 'active'},
#  {'ask_price': '35.450000',
#   'ask_size': 600,
#   'venue_ask_time': '2024-08-01T15:34:30.204Z',
#   'bid_price': '35.300000',
#   'bid_size': 200,
#   'venue_bid_time': '2024-08-01T15:34:30.204Z',
#   'last_trade_price': '35.480000',
#   'venue_last_trade_time': '2024-08-01T15:24:42.664Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '37.010000',
#   'adjusted_previous_close': '37.010000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'OMRNY',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:30Z',
#   'instrument': 'https://api.robinhood.com/instruments/575496c4-1d9e-465a-949e-90d5ffbe7759/',
#   'instrument_id': '575496c4-1d9e-465a-949e-90d5ffbe7759',
#   'state': 'active'},
#  {'ask_price': '139.910000',
#   'ask_size': 10,
#   'venue_ask_time': '2024-08-01T15:34:27.525495185Z',
#   'bid_price': '139.650000',
#   'bid_size': 210,
#   'venue_bid_time': '2024-08-01T15:34:27.525495185Z',
#   'last_trade_price': '139.660000',
#   'venue_last_trade_time': '2024-08-01T15:34:16.563185723Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '140.750000',
#   'adjusted_previous_close': '140.750000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'ENSG',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:27Z',
#   'instrument': 'https://api.robinhood.com/instruments/44c985d5-d535-4bf1-8933-1583dcd24c1d/',
#   'instrument_id': '44c985d5-d535-4bf1-8933-1583dcd24c1d',
#   'state': 'active'},
#  {'ask_price': '22.910000',
#   'ask_size': 146,
#   'venue_ask_time': '2024-08-01T15:34:20.414851861Z',
#   'bid_price': '22.830000',
#   'bid_size': 100,
#   'venue_bid_time': '2024-08-01T15:34:20.414851861Z',
#   'last_trade_price': '22.910000',
#   'venue_last_trade_time': '2024-08-01T15:32:49.991390008Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '23.740000',
#   'adjusted_previous_close': '23.740000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'MSBI',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:20Z',
#   'instrument': 'https://api.robinhood.com/instruments/fb8437d2-0bdf-4094-8936-3535feb2ed62/',
#   'instrument_id': 'fb8437d2-0bdf-4094-8936-3535feb2ed62',
#   'state': 'active'},
#  {'ask_price': '146.740000',
#   'ask_size': 1,
#   'venue_ask_time': '2024-08-01T15:34:32.203095176Z',
#   'bid_price': '146.570000',
#   'bid_size': 204,
#   'venue_bid_time': '2024-08-01T15:34:32.203095176Z',
#   'last_trade_price': '146.690000',
#   'venue_last_trade_time': '2024-08-01T15:34:19.611192397Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '142.300000',
#   'adjusted_previous_close': '142.300000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'DGX',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:32Z',
#   'instrument': 'https://api.robinhood.com/instruments/f003a8ab-aeac-4e3f-8357-215087838cff/',
#   'instrument_id': 'f003a8ab-aeac-4e3f-8357-215087838cff',
#   'state': 'active'},
#  {'ask_price': '71.110000',
#   'ask_size': 200,
#   'venue_ask_time': '2024-08-01T15:34:31.519798546Z',
#   'bid_price': '71.090000',
#   'bid_size': 200,
#   'venue_bid_time': '2024-08-01T15:34:31.519798546Z',
#   'last_trade_price': '71.122000',
#   'venue_last_trade_time': '2024-08-01T15:33:50.462286165Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '70.750000',
#   'adjusted_previous_close': '70.750000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'FHLC',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/084be07b-7eae-40ba-a49f-6e63a990a007/',
#   'instrument_id': '084be07b-7eae-40ba-a49f-6e63a990a007',
#   'state': 'active'},
#  {'ask_price': '107.820000',
#   'ask_size': 200,
#   'venue_ask_time': '2024-08-01T15:34:17.35146384Z',
#   'bid_price': '107.370000',
#   'bid_size': 200,
#   'venue_bid_time': '2024-08-01T15:34:17.35146384Z',
#   'last_trade_price': '106.705000',
#   'venue_last_trade_time': '2024-08-01T14:18:40.604023581Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '106.481700',
#   'adjusted_previous_close': '106.481700',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'RXL',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:17Z',
#   'instrument': 'https://api.robinhood.com/instruments/0beacb4c-bd5b-45f5-9afb-73256c62018d/',
#   'instrument_id': '0beacb4c-bd5b-45f5-9afb-73256c62018d',
#   'state': 'active'},
#  {'ask_price': '6.350000',
#   'ask_size': 300,
#   'venue_ask_time': '2024-08-01T15:33:40.285227962Z',
#   'bid_price': '6.270000',
#   'bid_size': 100,
#   'venue_bid_time': '2024-08-01T15:33:40.285227962Z',
#   'last_trade_price': '6.345000',
#   'venue_last_trade_time': '2024-08-01T15:30:39.922538796Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '6.300000',
#   'adjusted_previous_close': '6.300000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'PMM',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:33:40Z',
#   'instrument': 'https://api.robinhood.com/instruments/73abc9a2-fc60-4f86-b380-9dc6e3b0a900/',
#   'instrument_id': '73abc9a2-fc60-4f86-b380-9dc6e3b0a900',
#   'state': 'active'},
#  {'ask_price': '108.820000',
#   'ask_size': 28,
#   'venue_ask_time': '2024-08-01T15:33:50.873681458Z',
#   'bid_price': '108.500000',
#   'bid_size': 24,
#   'venue_bid_time': '2024-08-01T15:33:50.873681458Z',
#   'last_trade_price': '108.633200',
#   'venue_last_trade_time': '2024-08-01T15:31:55.907914574Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '110.010000',
#   'adjusted_previous_close': '110.010000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'HURN',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:33:50Z',
#   'instrument': 'https://api.robinhood.com/instruments/5f786f4d-a3c9-4fda-b755-232accf0a58b/',
#   'instrument_id': '5f786f4d-a3c9-4fda-b755-232accf0a58b',
#   'state': 'active'},
#  {'ask_price': '10.850000',
#   'ask_size': 447,
#   'venue_ask_time': '2024-08-01T15:34:21.279501Z',
#   'bid_price': '10.800000',
#   'bid_size': 100,
#   'venue_bid_time': '2024-08-01T15:34:21.279501Z',
#   'last_trade_price': '10.880000',
#   'venue_last_trade_time': '2024-08-01T15:31:18.296807626Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '11.220000',
#   'adjusted_previous_close': '11.220000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'TBRG',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:21Z',
#   'instrument': 'https://api.robinhood.com/instruments/7c0afffc-6775-4760-88ff-d90840e2aca9/',
#   'instrument_id': '7c0afffc-6775-4760-88ff-d90840e2aca9',
#   'state': 'active'},
#  {'ask_price': '51.030000',
#   'ask_size': 253,
#   'venue_ask_time': '2024-08-01T15:34:26.80927059Z',
#   'bid_price': '50.710000',
#   'bid_size': 12,
#   'venue_bid_time': '2024-08-01T15:34:26.80927059Z',
#   'last_trade_price': '50.840000',
#   'venue_last_trade_time': '2024-08-01T15:33:22.531655963Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '52.460000',
#   'adjusted_previous_close': '52.460000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'ASTH',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:26Z',
#   'instrument': 'https://api.robinhood.com/instruments/911a9133-5a61-4a93-81eb-8be1bce291ac/',
#   'instrument_id': '911a9133-5a61-4a93-81eb-8be1bce291ac',
#   'state': 'active'},
#  {'ask_price': '18.100000',
#   'ask_size': 210,
#   'venue_ask_time': '2024-08-01T15:34:31.075684166Z',
#   'bid_price': '18.000000',
#   'bid_size': 4,
#   'venue_bid_time': '2024-08-01T15:34:31.075684166Z',
#   'last_trade_price': '18.050000',
#   'venue_last_trade_time': '2024-08-01T15:34:15.387550503Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '19.350000',
#   'adjusted_previous_close': '19.350000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'INOD',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/648ebb85-e7b9-4c9e-82f0-2ac7526e35a7/',
#   'instrument_id': '648ebb85-e7b9-4c9e-82f0-2ac7526e35a7',
#   'state': 'active'},
#  {'ask_price': '58.280000',
#   'ask_size': 1100,
#   'venue_ask_time': '2024-08-01T15:34:31.12951589Z',
#   'bid_price': '58.080000',
#   'bid_size': 1000,
#   'venue_bid_time': '2024-08-01T15:34:31.12951589Z',
#   'last_trade_price': '58.094000',
#   'venue_last_trade_time': '2024-07-29T19:55:34Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '58.813800',
#   'adjusted_previous_close': '58.813800',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'SPXV',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/f9077804-e2c8-4b3f-9bb2-4bc02aa53133/',
#   'instrument_id': 'f9077804-e2c8-4b3f-9bb2-4bc02aa53133',
#   'state': 'active'},
#  {'ask_price': '11.120000',
#   'ask_size': 357,
#   'venue_ask_time': '2024-08-01T15:34:31.663562162Z',
#   'bid_price': '11.100000',
#   'bid_size': 212,
#   'venue_bid_time': '2024-08-01T15:34:31.663562162Z',
#   'last_trade_price': '11.110000',
#   'venue_last_trade_time': '2024-08-01T15:32:41.503760159Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '11.430000',
#   'adjusted_previous_close': '11.430000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'HCSG',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/6d42994e-3ff6-4ac5-9116-162421b9b0df/',
#   'instrument_id': '6d42994e-3ff6-4ac5-9116-162421b9b0df',
#   'state': 'active'},
#  {'ask_price': '76.520000',
#   'ask_size': 22,
#   'venue_ask_time': '2024-08-01T15:34:27.452503579Z',
#   'bid_price': '76.440000',
#   'bid_size': 270,
#   'venue_bid_time': '2024-08-01T15:34:27.452503579Z',
#   'last_trade_price': '76.450000',
#   'venue_last_trade_time': '2024-08-01T15:34:30.476531822Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '78.480000',
#   'adjusted_previous_close': '78.480000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'HQY',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:30Z',
#   'instrument': 'https://api.robinhood.com/instruments/10684996-c492-4d62-9d16-d6e61ee43726/',
#   'instrument_id': '10684996-c492-4d62-9d16-d6e61ee43726',
#   'state': 'active'},
#  {'ask_price': '26.110000',
#   'ask_size': 600,
#   'venue_ask_time': '2024-08-01T15:34:31.773505926Z',
#   'bid_price': '26.100000',
#   'bid_size': 321,
#   'venue_bid_time': '2024-08-01T15:34:31.773505926Z',
#   'last_trade_price': '26.105000',
#   'venue_last_trade_time': '2024-08-01T15:34:25.739806765Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '26.750000',
#   'adjusted_previous_close': '26.750000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'AVTR',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/e2466174-896d-4387-b16b-688ea8592368/',
#   'instrument_id': 'e2466174-896d-4387-b16b-688ea8592368',
#   'state': 'active'},
#  {'ask_price': '18.750000',
#   'ask_size': 200,
#   'venue_ask_time': '2024-08-01T15:32:27.987852299Z',
#   'bid_price': '18.550000',
#   'bid_size': 270,
#   'venue_bid_time': '2024-08-01T15:32:27.987852299Z',
#   'last_trade_price': '18.570000',
#   'venue_last_trade_time': '2024-08-01T15:30:38.919556101Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '18.570000',
#   'adjusted_previous_close': '18.570000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'HQH',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:32:27Z',
#   'instrument': 'https://api.robinhood.com/instruments/1254125b-7b52-4a22-925c-69ed3b1bcbb9/',
#   'instrument_id': '1254125b-7b52-4a22-925c-69ed3b1bcbb9',
#   'state': 'active'},
#  {'ask_price': '0.399800',
#   'ask_size': 2500,
#   'venue_ask_time': '2024-01-25T21:02:32.058Z',
#   'bid_price': '0.360000',
#   'bid_size': 2500,
#   'venue_bid_time': '2024-01-25T21:02:32.058Z',
#   'last_trade_price': '0.100000',
#   'venue_last_trade_time': '2024-08-01T15:11:45.191Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '0.020300',
#   'adjusted_previous_close': '0.035000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'RADCQ',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:11:45Z',
#   'instrument': 'https://api.robinhood.com/instruments/0f213bed-8ddc-41ca-847e-31711df31dab/',
#   'instrument_id': '0f213bed-8ddc-41ca-847e-31711df31dab',
#   'state': 'unlisted'},
#  {'ask_price': '213.980000',
#   'ask_size': 102,
#   'venue_ask_time': '2024-08-01T15:34:29.110084043Z',
#   'bid_price': '213.640000',
#   'bid_size': 200,
#   'venue_bid_time': '2024-08-01T15:34:29.110084043Z',
#   'last_trade_price': '213.640000',
#   'venue_last_trade_time': '2024-08-01T15:34:17.770390262Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '213.760000',
#   'adjusted_previous_close': '213.760000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'UHS',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:29Z',
#   'instrument': 'https://api.robinhood.com/instruments/24379325-6c9c-45c1-8861-651cf592603f/',
#   'instrument_id': '24379325-6c9c-45c1-8861-651cf592603f',
#   'state': 'active'},
#  {'ask_price': '111.280000',
#   'ask_size': 106,
#   'venue_ask_time': '2024-08-01T15:34:32.278294731Z',
#   'bid_price': '111.190000',
#   'bid_size': 60,
#   'venue_bid_time': '2024-08-01T15:34:32.278294731Z',
#   'last_trade_price': '111.268000',
#   'venue_last_trade_time': '2024-08-01T15:34:19.474675044Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '112.710000',
#   'adjusted_previous_close': '112.710000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'CBRE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:32Z',
#   'instrument': 'https://api.robinhood.com/instruments/d2be8e45-297b-4038-9e69-c049e884c450/',
#   'instrument_id': 'd2be8e45-297b-4038-9e69-c049e884c450',
#   'state': 'active'},
#  {'ask_price': '66.500000',
#   'ask_size': 2002,
#   'venue_ask_time': '2024-08-01T15:32:13.94Z',
#   'bid_price': '65.890000',
#   'bid_size': 1700,
#   'venue_bid_time': '2024-08-01T15:32:13.94Z',
#   'last_trade_price': '66.500000',
#   'venue_last_trade_time': '2024-08-01T15:28:54.811Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '66.810000',
#   'adjusted_previous_close': '66.810000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'LZAGY',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'consolidated',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:32:13Z',
#   'instrument': 'https://api.robinhood.com/instruments/2136240b-49ec-48bf-819c-de2b1e1fec02/',
#   'instrument_id': '2136240b-49ec-48bf-819c-de2b1e1fec02',
#   'state': 'active'},
#  {'ask_price': '8.630000',
#   'ask_size': 291,
#   'venue_ask_time': '2024-08-01T15:34:16.793423068Z',
#   'bid_price': '8.620000',
#   'bid_size': 39,
#   'venue_bid_time': '2024-08-01T15:34:16.793423068Z',
#   'last_trade_price': '8.630000',
#   'venue_last_trade_time': '2024-08-01T15:28:51.476642771Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '8.830000',
#   'adjusted_previous_close': '8.830000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'TPVG',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:16Z',
#   'instrument': 'https://api.robinhood.com/instruments/e4d93f1e-9219-4116-81b1-79cc1fb8bd2e/',
#   'instrument_id': 'e4d93f1e-9219-4116-81b1-79cc1fb8bd2e',
#   'state': 'active'},
#  {'ask_price': '154.010000',
#   'ask_size': 11,
#   'venue_ask_time': '2024-08-01T15:34:31.67844931Z',
#   'bid_price': '153.650000',
#   'bid_size': 31,
#   'venue_bid_time': '2024-08-01T15:34:31.67844931Z',
#   'last_trade_price': '153.770000',
#   'venue_last_trade_time': '2024-08-01T15:33:44.631950196Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '159.290000',
#   'adjusted_previous_close': '159.290000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'PI',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/7dc7e5c0-2614-4d9b-b201-1828e435fb35/',
#   'instrument_id': '7dc7e5c0-2614-4d9b-b201-1828e435fb35',
#   'state': 'active'},
#  {'ask_price': '15.510000',
#   'ask_size': 200,
#   'venue_ask_time': '2024-08-01T15:32:57.727102638Z',
#   'bid_price': '15.340000',
#   'bid_size': 100,
#   'venue_bid_time': '2024-08-01T15:32:57.727102638Z',
#   'last_trade_price': '15.360000',
#   'venue_last_trade_time': '2024-08-01T15:32:15.319198606Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '15.370000',
#   'adjusted_previous_close': '15.370000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'HQL',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:32:57Z',
# ...
#   'bid_price': '20.910000',
#   'bid_size': 1744,
#   'venue_bid_time': '2024-08-01T15:34:31.092735565Z',
#   'last_trade_price': '20.910000',
#   'venue_last_trade_time': '2024-08-01T15:34:30.48711105Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '20.940000',
#   'adjusted_previous_close': '20.940000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'ARCC',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/4f3f9073-872c-4ece-a9e1-1e3bb7f6fc16/',
#   'instrument_id': '4f3f9073-872c-4ece-a9e1-1e3bb7f6fc16',
#   'state': 'active'},
#  {'ask_price': '97.310000',
#   'ask_size': 297,
#   'venue_ask_time': '2024-08-01T15:34:29.904700331Z',
#   'bid_price': '97.130000',
#   'bid_size': 409,
#   'venue_bid_time': '2024-08-01T15:34:29.904700331Z',
#   'last_trade_price': '97.300000',
#   'venue_last_trade_time': '2024-08-01T15:34:27.716768738Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '102.020000',
#   'adjusted_previous_close': '102.020000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'UMBF',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:29Z',
#   'instrument': 'https://api.robinhood.com/instruments/25b40c3e-f156-430e-bf6b-a71631c68c16/',
#   'instrument_id': '25b40c3e-f156-430e-bf6b-a71631c68c16',
#   'state': 'active'},
#  {'ask_price': '568.900000',
#   'ask_size': 1,
#   'venue_ask_time': '2024-08-01T15:34:27.383337104Z',
#   'bid_price': '568.590000',
#   'bid_size': 20,
#   'venue_bid_time': '2024-08-01T15:34:27.383337104Z',
#   'last_trade_price': '568.830000',
#   'venue_last_trade_time': '2024-08-01T15:34:23.576969989Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '576.160000',
#   'adjusted_previous_close': '576.160000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'UNH',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:27Z',
#   'instrument': 'https://api.robinhood.com/instruments/1abfbfc7-6c65-4ded-8a97-1e7f82220b64/',
#   'instrument_id': '1abfbfc7-6c65-4ded-8a97-1e7f82220b64',
#   'state': 'active'},
#  {'ask_price': '35.250000',
#   'ask_size': 135,
#   'venue_ask_time': '2024-08-01T15:34:31.689818279Z',
#   'bid_price': '35.210000',
#   'bid_size': 100,
#   'venue_bid_time': '2024-08-01T15:34:31.689818279Z',
#   'last_trade_price': '35.250000',
#   'venue_last_trade_time': '2024-08-01T15:33:27.494064921Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '35.710000',
#   'adjusted_previous_close': '35.710000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'LTC',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/5e3b7549-7694-4a01-bffb-082623c6569e/',
#   'instrument_id': '5e3b7549-7694-4a01-bffb-082623c6569e',
#   'state': 'active'},
#  {'ask_price': '21.690000',
#   'ask_size': 405,
#   'venue_ask_time': '2024-08-01T15:34:30.582810659Z',
#   'bid_price': '21.680000',
#   'bid_size': 252,
#   'venue_bid_time': '2024-08-01T15:34:30.582810659Z',
#   'last_trade_price': '21.680000',
#   'venue_last_trade_time': '2024-08-01T15:34:31.785967599Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '21.820000',
#   'adjusted_previous_close': '21.820000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'DOC',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/61ce14ef-2831-4f73-b78d-0a94f7dcb15d/',
#   'instrument_id': '61ce14ef-2831-4f73-b78d-0a94f7dcb15d',
#   'state': 'active'},
#  {'ask_price': '17.380000',
#   'ask_size': 2434,
#   'venue_ask_time': '2024-08-01T15:34:25.099972292Z',
#   'bid_price': '17.370000',
#   'bid_size': 1120,
#   'venue_bid_time': '2024-08-01T15:34:25.099972292Z',
#   'last_trade_price': '17.375000',
#   'venue_last_trade_time': '2024-08-01T15:34:30.075998092Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '17.430000',
#   'adjusted_previous_close': '17.430000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'TEVA',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:30Z',
#   'instrument': 'https://api.robinhood.com/instruments/e93b7a10-a53e-46c8-9add-c717216eb25d/',
#   'instrument_id': 'e93b7a10-a53e-46c8-9add-c717216eb25d',
#   'state': 'active'},
#  {'ask_price': '3.120000',
#   'ask_size': 200,
#   'venue_ask_time': '2024-08-01T15:34:17.355867776Z',
#   'bid_price': '3.070000',
#   'bid_size': 100,
#   'venue_bid_time': '2024-08-01T15:34:17.355867776Z',
#   'last_trade_price': '3.070000',
#   'venue_last_trade_time': '2024-08-01T15:34:25.191170941Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '3.060000',
#   'adjusted_previous_close': '3.060000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'PRPH',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:25Z',
#   'instrument': 'https://api.robinhood.com/instruments/7733c3c8-cb9e-4cf7-bc23-3bf092bf285c/',
#   'instrument_id': '7733c3c8-cb9e-4cf7-bc23-3bf092bf285c',
#   'state': 'active'},
#  {'ask_price': '110.860000',
#   'ask_size': 50,
#   'venue_ask_time': '2024-08-01T15:34:19.471352333Z',
#   'bid_price': '110.530000',
#   'bid_size': 6,
#   'venue_bid_time': '2024-08-01T15:34:19.471352333Z',
#   'last_trade_price': '110.520000',
#   'venue_last_trade_time': '2024-08-01T15:32:57.960336369Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '112.090000',
#   'adjusted_previous_close': '112.090000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'AGYS',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:19Z',
#   'instrument': 'https://api.robinhood.com/instruments/180dc00f-0d91-492a-b203-b40ab992f855/',
#   'instrument_id': '180dc00f-0d91-492a-b203-b40ab992f855',
#   'state': 'active'},
#  {'ask_price': '9.490000',
#   'ask_size': 300,
#   'venue_ask_time': '2024-08-01T15:34:31.806659817Z',
#   'bid_price': '9.480000',
#   'bid_size': 106,
#   'venue_bid_time': '2024-08-01T15:34:31.806659817Z',
#   'last_trade_price': '9.490000',
#   'venue_last_trade_time': '2024-08-01T15:32:41.508177392Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '9.550000',
#   'adjusted_previous_close': '9.550000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'GMRE',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/23d06ee4-223e-4902-b7f6-aa635185842f/',
#   'instrument_id': '23d06ee4-223e-4902-b7f6-aa635185842f',
#   'state': 'active'},
#  {'ask_price': '70.950000',
#   'ask_size': 32,
#   'venue_ask_time': '2024-08-01T15:33:50.859254388Z',
#   'bid_price': '70.790000',
#   'bid_size': 3,
#   'venue_bid_time': '2024-08-01T15:33:50.859254388Z',
#   'last_trade_price': '70.750000',
#   'venue_last_trade_time': '2024-08-01T15:31:50.242036422Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '71.610000',
#   'adjusted_previous_close': '71.610000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'BRC',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:33:50Z',
#   'instrument': 'https://api.robinhood.com/instruments/630ee324-f444-4089-a7ba-b5b752b2097d/',
#   'instrument_id': '630ee324-f444-4089-a7ba-b5b752b2097d',
#   'state': 'active'},
#  {'ask_price': '109.210000',
#   'ask_size': 125,
#   'venue_ask_time': '2024-08-01T15:34:31.558551276Z',
#   'bid_price': '109.190000',
#   'bid_size': 350,
#   'venue_bid_time': '2024-08-01T15:34:31.558551276Z',
#   'last_trade_price': '109.200000',
#   'venue_last_trade_time': '2024-08-01T15:34:27.750893274Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '105.940000',
#   'adjusted_previous_close': '105.940000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'ABT',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/2018c0a7-2525-4dee-8de4-b6fb2c1f286e/',
#   'instrument_id': '2018c0a7-2525-4dee-8de4-b6fb2c1f286e',
#   'state': 'active'},
#  {'ask_price': '10.660000',
#   'ask_size': 200,
#   'venue_ask_time': '2024-08-01T15:34:18.001773005Z',
#   'bid_price': '10.450000',
#   'bid_size': 5,
#   'venue_bid_time': '2024-08-01T15:34:18.001773005Z',
#   'last_trade_price': '10.460000',
#   'venue_last_trade_time': '2024-08-01T15:28:47.380907251Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '11.570000',
#   'adjusted_previous_close': '11.570000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'DLHC',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:18Z',
#   'instrument': 'https://api.robinhood.com/instruments/c334e409-4b32-4522-8d25-a1459d238c81/',
#   'instrument_id': 'c334e409-4b32-4522-8d25-a1459d238c81',
#   'state': 'active'},
#  {'ask_price': '6.720000',
#   'ask_size': 85,
#   'venue_ask_time': '2024-08-01T15:32:57.635718639Z',
#   'bid_price': '6.590000',
#   'bid_size': 100,
#   'venue_bid_time': '2024-08-01T15:32:57.635718639Z',
#   'last_trade_price': '6.730000',
#   'venue_last_trade_time': '2024-08-01T15:09:36.229356276Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '6.900000',
#   'adjusted_previous_close': '6.900000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'INFU',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:32:57Z',
#   'instrument': 'https://api.robinhood.com/instruments/886516fa-b322-4422-bd40-6380ce49fede/',
#   'instrument_id': '886516fa-b322-4422-bd40-6380ce49fede',
#   'state': 'active'},
#  {'ask_price': '148.420000',
#   'ask_size': 32,
#   'venue_ask_time': '2024-08-01T15:32:09.520075132Z',
#   'bid_price': '148.170000',
#   'bid_size': 1,
#   'venue_bid_time': '2024-08-01T15:32:09.520075132Z',
#   'last_trade_price': '148.200000',
#   'venue_last_trade_time': '2024-08-01T15:29:29.319127592Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '150.590000',
#   'adjusted_previous_close': '150.590000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'RLI',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:32:09Z',
#   'instrument': 'https://api.robinhood.com/instruments/54248900-b8f9-4fa3-9bb9-6c79e20d73fa/',
#   'instrument_id': '54248900-b8f9-4fa3-9bb9-6c79e20d73fa',
#   'state': 'active'},
#  {'ask_price': '63.210000',
#   'ask_size': 667,
#   'venue_ask_time': '2024-08-01T15:34:31.519314932Z',
#   'bid_price': '63.190000',
#   'bid_size': 300,
#   'venue_bid_time': '2024-08-01T15:34:31.519314932Z',
#   'last_trade_price': '63.210000',
#   'venue_last_trade_time': '2024-08-01T15:33:45.892434575Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '62.830000',
#   'adjusted_previous_close': '62.830000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'IYH',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:31Z',
#   'instrument': 'https://api.robinhood.com/instruments/95c2ecb6-46f1-470e-b042-ec8ce4d70e4a/',
#   'instrument_id': '95c2ecb6-46f1-470e-b042-ec8ce4d70e4a',
#   'state': 'active'},
#  {'ask_price': '41.390000',
#   'ask_size': 100,
#   'venue_ask_time': '2024-08-01T15:34:23.155570333Z',
#   'bid_price': '41.370000',
#   'bid_size': 105,
#   'venue_bid_time': '2024-08-01T15:34:23.155570333Z',
#   'last_trade_price': '41.370000',
#   'venue_last_trade_time': '2024-08-01T15:34:02.942087869Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '41.400000',
#   'adjusted_previous_close': '41.400000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'SRDX',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:23Z',
#   'instrument': 'https://api.robinhood.com/instruments/5bb1a592-e1c4-455e-a1e8-358edb0ed0a7/',
#   'instrument_id': '5bb1a592-e1c4-455e-a1e8-358edb0ed0a7',
#   'state': 'active'},
#  {'ask_price': '67.040000',
#   'ask_size': 1,
#   'venue_ask_time': '2024-08-01T15:34:18.970863477Z',
#   'bid_price': '67.000000',
#   'bid_size': 407,
#   'venue_bid_time': '2024-08-01T15:34:18.970863477Z',
#   'last_trade_price': '67.030000',
#   'venue_last_trade_time': '2024-08-01T15:33:01.886556338Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '67.840000',
#   'adjusted_previous_close': '67.840000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'SEIC',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:18Z',
#   'instrument': 'https://api.robinhood.com/instruments/1f9ffa11-9197-4675-b144-d826daa571fc/',
#   'instrument_id': '1f9ffa11-9197-4675-b144-d826daa571fc',
#   'state': 'active'},
#  {'ask_price': '15.480000',
#   'ask_size': 717,
#   'venue_ask_time': '2024-08-01T15:34:32.148409313Z',
#   'bid_price': '15.470000',
#   'bid_size': 1001,
#   'venue_bid_time': '2024-08-01T15:34:32.148409313Z',
#   'last_trade_price': '15.476900',
#   'venue_last_trade_time': '2024-08-01T15:34:30.786751493Z',
#   'last_extended_hours_trade_price': None,
#   'last_non_reg_trade_price': None,
#   'venue_last_non_reg_trade_time': None,
#   'previous_close': '15.520000',
#   'adjusted_previous_close': '15.520000',
#   'previous_close_date': '2024-07-31',
#   'symbol': 'OBDC',
#   'trading_halted': False,
#   'has_traded': True,
#   'last_trade_price_source': 'nls',
#   'last_non_reg_trade_price_source': '',
#   'updated_at': '2024-08-01T15:34:32Z',
#   'instrument': 'https://api.robinhood.com/instruments/8546a8c8-0bfa-4a09-b40c-c902203a7e83/',
#   'instrument_id': '8546a8c8-0bfa-4a09-b40c-c902203a7e83',
#   'state': 'active'}]
